# %% [markdown]
# ## 5 word to 1 word loss=0.0237

# %%
#	program to find next word given 3 words using 
#	LSTM rnn by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a words vocabulary,
words=set([c for c in text.split()]) 
nb_words=len(words)

word2index=	dict((c,i) for i,c in enumerate(words))
index2word=	dict((i,c) for i,c in enumerate(words))
print(nb_words)

no_of_words=5
input_words = []
label_words = []
words_list=text.split()
for i in range(0, len(words_list) - no_of_words):
	input_words.append(words_list[i:i+no_of_words])
	label_words.append(words_list[i+no_of_words])

    
#preparing training data
import numpy as np
x=np.zeros((len(input_words),no_of_words,nb_words),dtype=np.bool)
y=np.zeros((len(input_words),nb_words),dtype=np.bool)
for i,input_word in enumerate(input_words):
    for j,word in enumerate(input_word):
        x[i,j,word2index[word]]=1
    y[i,word2index[label_words[i]]]=1
    
#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 128
NUM_ITERATIONS = 5
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(no_of_words,nb_words,)))
model.add(Dense(nb_words))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_words))
    test_words = input_words[test_idx]
    print("Generating from seed: %s" % (test_words))
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1,no_of_words, nb_words))
        for i,word in enumerate(test_words):
            Xtest[0, i, word2index[word]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2word[np.argmax(pred)]
        print(ypred, end=" ")
        # move forward with test_chars + ypred
        test_words =test_words[1:]+[ypred]
print()
# Out:
# 619
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_11 (LSTM)               (None, 128)               382976
# _________________________________________________________________
# dense_11 (Dense)             (None, 619)               79851
# _________________________________________________________________
# activation_11 (Activation)   (None, 619)               0
# ...
# Total params: 462,827
# Trainable params: 462,827
# Non-trainable params: 0
# _________________________________________________________________
# ...
# Iteration #: 0
# Epoch 1/50
# 1740/1740 [==============================] - 2s 1ms/step - loss: 6.3959
# Epoch 2/50
# 1740/1740 [==============================] - 1s 574us/step - loss: 5.8278
# Epoch 3/50
# 1740/1740 [==============================] - 1s 581us/step - loss: 5.5180
# Epoch 4/50
# 1740/1740 [==============================] - 1s 582us/step - loss: 5.4718
# Epoch 5/50
# ...

# %% [markdown]
# ## 3 word to 1 word loss=0.0827

# %%
#	program to find next word given 3 words using 
#	LSTM rnn by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a words vocabulary,
words=set([c for c in text.split()]) 
nb_words=len(words)

word2index=	dict((c,i) for i,c in enumerate(words))
index2word=	dict((i,c) for i,c in enumerate(words))
print(nb_words)

no_of_words=3
input_words = []
label_words = []
words_list=text.split()
for i in range(0, len(words_list) - no_of_words):
	input_words.append(words_list[i:i+no_of_words])
	label_words.append(words_list[i+no_of_words])

    
#preparing training data
import numpy as np
x=np.zeros((len(input_words),no_of_words,nb_words),dtype=np.bool)
y=np.zeros((len(input_words),nb_words),dtype=np.bool)
for i,input_word in enumerate(input_words):
    for j,word in enumerate(input_word):
        x[i,j,word2index[word]]=1
    y[i,word2index[label_words[i]]]=1
    
#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 128
NUM_ITERATIONS = 5
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(no_of_words,nb_words,)))
model.add(Dense(nb_words))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_words))
    test_words = input_words[test_idx]
    print("Generating from seed: %s" % (test_words))
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1,no_of_words, nb_words))
        for i,word in enumerate(test_words):
            Xtest[0, i, word2index[word]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2word[np.argmax(pred)]
        print(ypred, end=" ")
        # move forward with test_chars + ypred
        test_words =test_words[1:]+[ypred]
print()
# Out:
# 619
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_10 (LSTM)               (None, 128)               382976
# _________________________________________________________________
# dense_10 (Dense)             (None, 619)               79851
# _________________________________________________________________
# activation_10 (Activation)   (None, 619)               0
# ...
# Total params: 462,827
# Trainable params: 462,827
# Non-trainable params: 0
# _________________________________________________________________
# ...
# Iteration #: 0
# Epoch 1/50
# 1742/1742 [==============================] - 2s 1ms/step - loss: 6.4102
# Epoch 2/50
# 1742/1742 [==============================] - 1s 504us/step - loss: 6.2686
# Epoch 3/50
# 1742/1742 [==============================] - 1s 475us/step - loss: 5.7899
# Epoch 4/50
# 1742/1742 [==============================] - 1s 465us/step - loss: 5.4966
# Epoch 5/50
# ...

# %% [markdown]
# ## 2 word to 1 word loss=0.3055 (iteration=10,epoch for each iteration=50)

# %%
#	program to find next word given 2 words using 
#	LSTM rnn by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a words vocabulary,
words=set([c for c in text.split()]) 
nb_words=len(words)

word2index=	dict((c,i) for i,c in enumerate(words))
index2word=	dict((i,c) for i,c in enumerate(words))
print(nb_words)

no_of_words=2
input_words = []
label_words = []
words_list=text.split()
for i in range(0, len(words_list) - no_of_words):
	input_words.append(words_list[i:i+no_of_words])
	label_words.append(words_list[i+no_of_words])

    
#preparing training data
import numpy as np
x=np.zeros((len(input_words),no_of_words,nb_words),dtype=np.bool)
y=np.zeros((len(input_words),nb_words),dtype=np.bool)
for i,input_word in enumerate(input_words):
    for j,word in enumerate(input_word):
        x[i,j,word2index[word]]=1
    y[i,word2index[label_words[i]]]=1
    
#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 256
NUM_ITERATIONS = 10
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(no_of_words,nb_words,)))
model.add(Dense(nb_words))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_words))
    test_words = input_words[test_idx]
    print("Generating from seed: %s" % (test_words))
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1,no_of_words, nb_words))
        for i,word in enumerate(test_words):
            Xtest[0, i, word2index[word]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2word[np.argmax(pred)]
        print(ypred, end=" ")
        # move forward with test_chars + ypred
        test_words =test_words[1:]+[ypred]
print()
# Out:
# 619
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_14 (LSTM)               (None, 128)               382976
# _________________________________________________________________
# dense_14 (Dense)             (None, 619)               79851
# _________________________________________________________________
# activation_14 (Activation)   (None, 619)               0
# ...
# Total params: 462,827
# Trainable params: 462,827
# Non-trainable params: 0
# _________________________________________________________________
# ...
# Iteration #: 0
# Epoch 1/50
# 1743/1743 [==============================] - 2s 1ms/step - loss: 6.4211
# Epoch 2/50
# 1743/1743 [==============================] - 1s 323us/step - loss: 6.3943
# Epoch 3/50
# 1743/1743 [==============================] - 1s 333us/step - loss: 6.3583
# Epoch 4/50
# 1743/1743 [==============================] - 1s 311us/step - loss: 6.3002
# Epoch 5/50
# ...

# %% [markdown]
# ## 1 word to 1 word loss=1.6094 (iteration=10,epoch for each iteration=50)

# %%
#	program to find next word given 2 words using 
#	LSTM rnn by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a words vocabulary,
words=set([c for c in text.split()]) 
nb_words=len(words)

word2index=	dict((c,i) for i,c in enumerate(words))
index2word=	dict((i,c) for i,c in enumerate(words))
print(nb_words)

no_of_words=1
input_words = []
label_words = []
words_list=text.split()
for i in range(0, len(words_list) - no_of_words):
	input_words.append(words_list[i:i+no_of_words])
	label_words.append(words_list[i+no_of_words])

    
#preparing training data
import numpy as np
x=np.zeros((len(input_words),no_of_words,nb_words),dtype=np.bool)
y=np.zeros((len(input_words),nb_words),dtype=np.bool)
for i,input_word in enumerate(input_words):
    for j,word in enumerate(input_word):
        x[i,j,word2index[word]]=1
    y[i,word2index[label_words[i]]]=1
    
#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 256
NUM_ITERATIONS = 10
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(no_of_words,nb_words,)))
model.add(Dense(nb_words))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_words))
    test_words = input_words[test_idx]
    print("Generating from seed: %s" % (test_words))
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1,no_of_words, nb_words))
        for i,word in enumerate(test_words):
            Xtest[0, i, word2index[word]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2word[np.argmax(pred)]
        print(ypred, end=" ")
        # move forward with test_chars + ypred
        test_words =test_words[1:]+[ypred]
print()
# Out:
# 619
# /home/santhosh/anaconda3/envs/pydl/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 128)               382976
# _________________________________________________________________
# dense_1 (Dense)              (None, 619)               79851
# _________________________________________________________________
# activation_1 (Activation)    (None, 619)               0
# ...
# Total params: 462,827
# Trainable params: 462,827
# Non-trainable params: 0
# _________________________________________________________________
# ...
# Iteration #: 0
# Epoch 1/50
# ...
