# %% [markdown]
# ## 10-char to 1 char loss=0.0770

# %%
#	program to find next character given five characters using 
#	lstm by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a characters vocabulary,
chars=set([c for c in text]) 
nb_chars=len(chars)
char2index=	dict((c,i) for i,c in enumerate(chars))
index2char=	dict((i,c) for i,c in enumerate(chars))
print(nb_chars)

SEQLEN = 10
STEP = 1
input_chars = []
label_chars = []
for i in range(0, len(text) - SEQLEN, STEP):
	input_chars.append(text[i:i + SEQLEN])
	label_chars.append(text[i + SEQLEN])

#preparing training data
import numpy as np
x=np.zeros((len(input_chars),SEQLEN,nb_chars),dtype=np.bool)
y=np.zeros((len(input_chars),nb_chars),dtype=np.bool)
for i,input_char in enumerate(input_chars):
	for j,ch in enumerate(input_char):
		x[i,j,char2index[ch]]=1
	y[i,char2index[label_chars[i]]]=1

#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 128
NUM_ITERATIONS = 5
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(SEQLEN,nb_chars,)))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1, SEQLEN, nb_chars))
        for i, ch in enumerate(test_chars):
            Xtest[0, i, char2index[ch]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print('(',test_chars,',',test_chars[1:] +ypred, end="),")
        # move forward with test_chars + ypred
        test_chars = test_chars[1:] + ypred
print()
# Out:
# 36
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 128)               84480
# _________________________________________________________________
# dense_5 (Dense)              (None, 36)                4644
# _________________________________________________________________
# activation_5 (Activation)    (None, 36)                0
# =================================================================
# Total params: 89,124
# Trainable params: 89,124
# Non-trainable params: 0
# _________________________________________________________________
# ==================================================
# Iteration #: 0
# Epoch 1/50
# 8962/8962 [==============================] - 4s 446us/step - loss: 2.9594
# Epoch 2/50
# 8962/8962 [==============================] - 3s 296us/step - loss: 2.8148
# Epoch 3/50
# 8962/8962 [==============================] - 3s 291us/step - loss: 2.6918
# Epoch 4/50
# 8962/8962 [==============================] - 3s 288us/step - loss: 2.5403
# Epoch 5/50
# 8962/8962 [==============================] - 3s 298us/step - loss: 2.4124
# Epoch 6/50
# 8962/8962 [==============================] - 3s 334us/step - loss: 2.3160
# Epoch 7/50
# 8962/8962 [==============================] - 3s 352us/step - loss: 0.0786
# Epoch 29/50
# 8962/8962 [==============================] - 3s 334us/step - loss: 0.0789
# Epoch 30/50
# 8962/8962 [==============================] - 3s 341us/step - loss: 0.0791
# Epoch 31/50
# 8962/8962 [==============================] - 3s 334us/step - loss: 0.0785
# Epoch 32/50
# 8962/8962 [==============================] - 3s 343us/step - loss: 0.0790
# Epoch 33/50
# 8962/8962 [==============================] - 3s 326us/step - loss: 0.0793
# Epoch 34/50
# 8962/8962 [==============================] - 3s 299us/step - loss: 0.0782
# Epoch 35/50
# 8962/8962 [==============================] - 3s 315us/step - loss: 0.0717
# Epoch 36/50
# 8962/8962 [==============================] - 3s 302us/step - loss: 0.0786
# Epoch 37/50
# 8962/8962 [==============================] - 3s 303us/step - loss: 0.0775
# Epoch 38/50
# 8962/8962 [==============================] - 3s 305us/step - loss: 0.0775
# Epoch 39/50
# 8962/8962 [==============================] - 3s 284us/step - loss: 0.0788
# Epoch 40/50
# 8962/8962 [==============================] - 3s 303us/step - loss: 0.0777
# Epoch 41/50
# 8962/8962 [==============================] - 3s 291us/step - loss: 0.0777
# Epoch 42/50
# 8962/8962 [==============================] - 3s 286us/step - loss: 0.0773
# Epoch 43/50
# 8962/8962 [==============================] - 3s 297us/step - loss: 0.0785
# Epoch 44/50
# 8962/8962 [==============================] - 3s 287us/step - loss: 0.0760
# Epoch 45/50
# 8962/8962 [==============================] - 3s 310us/step - loss: 0.0780
# Epoch 46/50
# 8962/8962 [==============================] - 3s 311us/step - loss: 0.0776
# Epoch 47/50
# 8962/8962 [==============================] - 3s 330us/step - loss: 0.0776
# Epoch 48/50
# 8962/8962 [==============================] - 3s 309us/step - loss: 0.0760
# Epoch 49/50
# 8962/8962 [==============================] - 3s 366us/step - loss: 0.0757
# Epoch 50/50
# 8962/8962 [==============================] - 3s 307us/step - loss: 0.0770
# Generating from seed: white bird
# white bird( white bird , hite birds),( hite birds , ite birds;),( ite birds; , te birds; ),( te birds;  , e birds; a),( e birds; a ,  birds; an),(  birds; an , birds; and),( birds; and , irds; and ),( irds; and  , rds; and t),( rds; and t , ds; and to),( ds; and to , s; and to ),( s; and to  , ; and to l),( ; and to l ,  and to li),(  and to li , and to lis),( and to lis , nd to list),( nd to list , d to liste),( d to liste ,  to listen),(  to listen , to listen ),( to listen  , o listen t),( o listen t ,  listen to),(  listen to , listen to ),( listen to  , isten to t),( isten to t , sten to th),( sten to th , ten to the),( ten to the , en to the ),( en to the  , n to the w),

# %% [markdown]
# ## 5-char to 1 char loss= 0.4292

# %%
#	program to find next character given five characters using 
#	lstm by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a characters vocabulary,
chars=set([c for c in text]) 
nb_chars=len(chars)
char2index=	dict((c,i) for i,c in enumerate(chars))
index2char=	dict((i,c) for i,c in enumerate(chars))
print(nb_chars)

SEQLEN = 5
STEP = 1
input_chars = []
label_chars = []
for i in range(0, len(text) - SEQLEN, STEP):
	input_chars.append(text[i:i + SEQLEN])
	label_chars.append(text[i + SEQLEN])

#preparing training data
import numpy as np
x=np.zeros((len(input_chars),SEQLEN,nb_chars),dtype=np.bool)
y=np.zeros((len(input_chars),nb_chars),dtype=np.bool)
for i,input_char in enumerate(input_chars):
	for j,ch in enumerate(input_char):
		x[i,j,char2index[ch]]=1
	y[i,char2index[label_chars[i]]]=1

#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 128
NUM_ITERATIONS = 5
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(SEQLEN,nb_chars,)))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1, SEQLEN, nb_chars))
        for i, ch in enumerate(test_chars):
            Xtest[0, i, char2index[ch]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print('(',test_chars,',',test_chars[1:] +ypred, end="),")
        # move forward with test_chars + ypred
        test_chars = test_chars[1:] + ypred
print()
# Out:
# 36
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 128)               84480
# _________________________________________________________________
# dense_4 (Dense)              (None, 36)                4644
# _________________________________________________________________
# activation_4 (Activation)    (None, 36)                0
# =================================================================
# Total params: 89,124
# Trainable params: 89,124
# Non-trainable params: 0
# _________________________________________________________________
# ==================================================
# Iteration #: 0
# Epoch 1/50
# 8967/8967 [==============================] - 3s 332us/step - loss: 2.9977
# Epoch 2/50
# 8967/8967 [==============================] - 2s 172us/step - loss: 2.7913
# Epoch 3/50
# 8967/8967 [==============================] - 2s 186us/step - loss: 2.6402
# Epoch 4/50
# 8967/8967 [==============================] - 2s 179us/step - loss: 2.4857
# Epoch 5/50
# 8967/8967 [==============================] - 1s 167us/step - loss: 2.3526
# Epoch 6/50
# 8967/8967 [==============================] - 2s 169us/step - loss: 2.2626
# Epoch 7/50
# 8967/8967 [==============================] - 2s 181us/step - loss: 2.1937
# Epoch 8/50
# 8967/8967 [==============================] - 2s 172us/step - loss: 2.1411
# Epoch 9/50
# 8967/8967 [==============================] - 1s 164us/step - loss: 2.0955
# Epoch 10/50
# 8967/8967 [==============================] - 2s 169us/step - loss: 2.0558
# Epoch 11/50
# 8967/8967 [==============================] - 1s 167us/step - loss: 2.0217
# Epoch 12/50
# 8967/8967 [==============================] - 2s 170us/step - loss: 1.9900
# Epoch 13/50
50
# 8967/8967 [==============================] - 2s 176us/step - loss: 0.6675
# Epoch 38/50
# 8967/8967 [==============================] - 2s 193us/step - loss: 0.6622
# Epoch 39/50
# 8967/8967 [==============================] - 2s 173us/step - loss: 0.6542
# Epoch 40/50
# 8967/8967 [==============================] - 2s 178us/step - loss: 0.6438
# Epoch 41/50
# 8967/8967 [==============================] - 2s 180us/step - loss: 0.6366
# Epoch 42/50
# 8967/8967 [==============================] - 2s 173us/step - loss: 0.6330
# Epoch 43/50
# 8967/8967 [==============================] - 2s 178us/step - loss: 0.6259
# Epoch 44/50
# 8967/8967 [==============================] - 2s 176us/step - loss: 0.6168
# Epoch 45/50
# 8967/8967 [==============================] - 2s 176us/step - loss: 0.6140
# Epoch 46/50
# 8967/8967 [==============================] - 2s 183us/step - loss: 0.6089
# Epoch 47/50
# 8967/8967 [==============================] - 2s 204us/step - loss: 0.6022
# Epoch 48/50
# 8967/8967 [==============================] - 2s 178us/step - loss: 0.5968
# Epoch 49/50
# 8967/8967 [==============================] - 2s 186us/step - loss: 0.5901
# Epoch 50/50
# 8967/8967 [==============================] - 2s 183us/step - loss: 0.5843
# Generating from seed: by fa
# by fa( by fa , y fan),( y fan ,  fann),(  fann , fanny),( fanny , anny ),( anny  , nny i),( nny i , ny in),( ny in , y in ),( y in  ,  in t),(  in t , in th),( in th , n the),( n the ,  the ),(  the  , the t),( the t , he tr),( he tr , e tra),( e tra ,  trav),(  trav , trave),( trave , ravel),( ravel , avell),( avell , velle),( velle , eller),( eller , ller ),( ller  , ler l),( ler l , er lo),( er lo , r los),( r los ,  lost),==================================================
# Iteration #: 2
# Epoch 1/50
# 8967/8967 [==============================] - 2s 193us/step - loss: 0.5785
# Epoch 2/50
# 8967/8967 [==============================] - 2s 182us/step - loss: 0.5751
# Epoch 3/50
# 8967/8967 [==============================] - 2s 179us/step - loss: 0.5729
# Epoch 4/50
# 8967/8967 [==============================] - 2s 176us/step - loss: 0.5650
# Epoch 5/50
# 8967/8967 [==============================] - 2s 178us/step - loss: 0.5617
# Epoch 6/50
# 8967/8967 [==============================] - 2s 179us/step - loss: 0.5600
# Epoch 7/50
# 8967/8967 [==============================] - 2s 178us/step - loss: 0.5508
# Epoch 8/50
# 8967/8967 [==============================] - 2s 184us/step - loss: 0.5495
# Epoch 9/50
# 8967/8967 [==============================] - 2s 188us/step - loss: 0.5455
# Epoch 10/50
# 8967/8967 [==============================] - 2s 186us/step - loss: 0.5416
# Epoch 11/50
# 8967/8967 [==============================] - 2s 182us/step - loss: 0.5406
# Epoch 12/50
# 8967/8967 [==============================] - 2s 181us/step - loss: 0.5355
# Epoch 13/50
# 8967/8967 [==============================] - 2s 175us/step - loss: 0.5333
# Epoch 14/50
# 8967/8967 [==============================] - 2s 189us/step - loss: 0.5292
# Epoch 15/50
# 8967/8967 [==============================] - 2s 190us/step - loss: 0.5264
# Epoch 16/50
# 8967/8967 [==============================] - 2s 190us/step - loss: 0.5229
# Epoch 17/50
# 8967/8967 [==============================] - 2s 193us/step - loss: 0.5201
# Epoch 18/50
# 8967/8967 [==============================] - 2s 195us/step - loss: 0.5186
# Epoch 19/50
# 8967/8967 [==============================] - 1s 160us/step - loss: 0.5165
# Epoch 20/50
# 8967/8967 [==============================] - 2s 169us/step - loss: 0.5118
# Epoch 21/50
# 8967/8967 [==============================] - 2s 196us/step - loss: 0.5106
# Epoch 22/50
50
# 8967/8967 [==============================] - 2s 176us/step - loss: 0.4357
# Epoch 22/50
# 8967/8967 [==============================] - 2s 183us/step - loss: 0.4367
# Epoch 23/50
# 8967/8967 [==============================] - 2s 181us/step - loss: 0.4349
# Epoch 24/50
# 8967/8967 [==============================] - 2s 175us/step - loss: 0.4346
# Epoch 25/50
# 8967/8967 [==============================] - 2s 176us/step - loss: 0.4348
# Epoch 26/50
# 8967/8967 [==============================] - 2s 173us/step - loss: 0.4376
# Epoch 27/50
# 8967/8967 [==============================] - 2s 192us/step - loss: 0.4325
# Epoch 28/50
# 8967/8967 [==============================] - 2s 233us/step - loss: 0.4347
# Epoch 29/50
# 8967/8967 [==============================] - 2s 207us/step - loss: 0.4357
# Epoch 30/50
# 8967/8967 [==============================] - 2s 205us/step - loss: 0.4348
# Epoch 31/50
# 8967/8967 [==============================] - 2s 199us/step - loss: 0.4327
# Epoch 32/50
# 8967/8967 [==============================] - 2s 209us/step - loss: 0.4332
# Epoch 33/50
# 8967/8967 [==============================] - 2s 203us/step - loss: 0.4332
# Epoch 34/50
# 8967/8967 [==============================] - 2s 203us/step - loss: 0.4344
# Epoch 35/50
# 8967/8967 [==============================] - 2s 198us/step - loss: 0.4312
# Epoch 36/50
# 8967/8967 [==============================] - 2s 203us/step - loss: 0.4312
# Epoch 37/50
# 8967/8967 [==============================] - 2s 209us/step - loss: 0.4329
# Epoch 38/50
# 8967/8967 [==============================] - 2s 191us/step - loss: 0.4348
# Epoch 39/50
# 8967/8967 [==============================] - 2s 203us/step - loss: 0.4328
# Epoch 40/50
# 8967/8967 [==============================] - 2s 209us/step - loss: 0.4270
# Epoch 41/50
# 8967/8967 [==============================] - 2s 194us/step - loss: 0.4338
# Epoch 42/50
# 8967/8967 [==============================] - 2s 191us/step - loss: 0.4301
# Epoch 43/50
# 8967/8967 [==============================] - 2s 195us/step - loss: 0.4328
# Epoch 44/50
# 8967/8967 [==============================] - 2s 199us/step - loss: 0.4327
# Epoch 45/50
# 8967/8967 [==============================] - 2s 193us/step - loss: 0.4323
# Epoch 46/50
# 8967/8967 [==============================] - 2s 190us/step - loss: 0.4319
# Epoch 47/50
# 8967/8967 [==============================] - 2s 199us/step - loss: 0.4304
# Epoch 48/50
# 8967/8967 [==============================] - 2s 198us/step - loss: 0.4290
# Epoch 49/50
# 8967/8967 [==============================] - 2s 192us/step - loss: 0.4268
# Epoch 50/50
# 8967/8967 [==============================] - 2s 200us/step - loss: 0.4292
# Generating from seed: se, a
# se, a( se, a , e, an),( e, an , , and),( , and ,  and ),(  and  , and t),( and t , nd th),( nd th , d the),( d the ,  the ),(  the  , the s),( the s , he su),( he su , e sun),( e sun ,  suns),(  suns , sunse),( sunse , unset),( unset , nset ),( nset  , set t),( set t , et to),( et to , t to ),( t to  ,  to c),(  to c , to co),( to co , o com),( o com ,  come),(  come , come ),( come  , ome a),( ome a , me an),( me an , e and),

# %% [markdown]
# ## 2-char to 1 char loss: 1.5509

# %%
#	program to find next character given five characters using 
#	lstm by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a characters vocabulary,
chars=set([c for c in text]) 
nb_chars=len(chars)
char2index=	dict((c,i) for i,c in enumerate(chars))
index2char=	dict((i,c) for i,c in enumerate(chars))
print(nb_chars)

SEQLEN = 2
STEP = 1
input_chars = []
label_chars = []
for i in range(0, len(text) - SEQLEN, STEP):
	input_chars.append(text[i:i + SEQLEN])
	label_chars.append(text[i + SEQLEN])

#preparing training data
import numpy as np
x=np.zeros((len(input_chars),SEQLEN,nb_chars),dtype=np.bool)
y=np.zeros((len(input_chars),nb_chars),dtype=np.bool)
for i,input_char in enumerate(input_chars):
	for j,ch in enumerate(input_char):
		x[i,j,char2index[ch]]=1
	y[i,char2index[label_chars[i]]]=1

#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 128
NUM_ITERATIONS = 5
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(SEQLEN,nb_chars,)))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1, SEQLEN, nb_chars))
        for i, ch in enumerate(test_chars):
            Xtest[0, i, char2index[ch]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print('(',test_chars,',',test_chars[1:] +ypred, end="),")
        # move forward with test_chars + ypred
        test_chars = test_chars[1:] + ypred
print()
# Out:
# 36
# /home/santhosh/anaconda3/envs/pydl/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               84480
# _________________________________________________________________
# dense_1 (Dense)              (None, 36)                4644
# _________________________________________________________________
# activation_1 (Activation)    (None, 36)                0
# =================================================================
# Total params: 89,124
# Trainable params: 89,124
# Non-trainable params: 0
# _________________________________________________________________
# ==================================================
# Iteration #: 0
# Epoch 1/50
# 8970/8970 [==============================] - 1s 159us/step - loss: 3.1869
# Epoch 2/50
# 8970/8970 [==============================] - 1s 87us/step - loss: 2.7558
# Epoch 3/50
# 8970/8970 [==============================] - 1s 96us/step - loss: 2.5753
# Epoch 4/50
# 8970/8970 [==============================] - 1s 103us/step - loss: 2.4330
# Epoch 5/50
# 8970/8970 [==============================] - 1s 92us/step - loss: 2.3183
# Epoch 6/50
# 8970/8970 [==============================] - 1s 101us/step - loss: 2.2403
# Epoch 7/50
# 8970/8970 [==============================] - 1s 94us/step - loss: 2.1890
# Epoch 8/50
# 8970/8970 [==============================] - 1s 97us/step - loss: 2.1505
# Epoch 9/50
# 8970/8970 [==============================] - 1s 99us/step - loss: 2.1193
# Epoch 10/50
# 8970/8970 [==============================] - 1s 90us/step - loss: 2.0926
# Epoch 11/50
# 8970/8970 [==============================] - 1s 95us/step - loss: 2.0712
# Epoch 12/50
# 8970/8970 [==============================] - 1s 116us/step - loss: 2.0510
# Epoch 13/50
# 8970/8970 [==============================] - 1s 157us/step - loss: 2.0305
# Epoch 14/50
50
# 8970/8970 [==============================] - 1s 91us/step - loss: 1.5564
# Epoch 19/50
# 8970/8970 [==============================] - 1s 91us/step - loss: 1.5554
# Epoch 20/50
# 8970/8970 [==============================] - 1s 91us/step - loss: 1.5560
# Epoch 21/50
# 8970/8970 [==============================] - 1s 92us/step - loss: 1.5551
# Epoch 22/50
# 8970/8970 [==============================] - 1s 92us/step - loss: 1.5546
# Epoch 23/50
# 8970/8970 [==============================] - 1s 90us/step - loss: 1.5539
# Epoch 24/50
# 8970/8970 [==============================] - 1s 90us/step - loss: 1.5558
# Epoch 25/50
# 8970/8970 [==============================] - 1s 91us/step - loss: 1.5543
# Epoch 26/50
# 8970/8970 [==============================] - 1s 92us/step - loss: 1.5543
# Epoch 27/50
# 8970/8970 [==============================] - 1s 100us/step - loss: 1.5543
# Epoch 28/50
# 8970/8970 [==============================] - 1s 99us/step - loss: 1.5546
# Epoch 29/50
# 8970/8970 [==============================] - 1s 99us/step - loss: 1.5529
# Epoch 30/50
# 8970/8970 [==============================] - 1s 98us/step - loss: 1.5523
# Epoch 31/50
# 8970/8970 [==============================] - 1s 96us/step - loss: 1.5534
# Epoch 32/50
# 8970/8970 [==============================] - 1s 100us/step - loss: 1.5539
# Epoch 33/50
# 8970/8970 [==============================] - 1s 90us/step - loss: 1.5536
# Epoch 34/50
# 8970/8970 [==============================] - 1s 98us/step - loss: 1.5525
# Epoch 35/50
# 8970/8970 [==============================] - 1s 97us/step - loss: 1.5536
# Epoch 36/50
# 8970/8970 [==============================] - 1s 94us/step - loss: 1.5530
# Epoch 37/50
# 8970/8970 [==============================] - 1s 97us/step - loss: 1.5529
# Epoch 38/50
# 8970/8970 [==============================] - 1s 93us/step - loss: 1.5519
# Epoch 39/50
# 8970/8970 [==============================] - 1s 99us/step - loss: 1.5518
# Epoch 40/50
# 8970/8970 [==============================] - 1s 94us/step - loss: 1.5532
# Epoch 41/50
# 8970/8970 [==============================] - 1s 96us/step - loss: 1.5512
# Epoch 42/50
# 8970/8970 [==============================] - 1s 93us/step - loss: 1.5519
# Epoch 43/50
# 8970/8970 [==============================] - 1s 99us/step - loss: 1.5514
# Epoch 44/50
# 8970/8970 [==============================] - 1s 91us/step - loss: 1.5522
# Epoch 45/50
# 8970/8970 [==============================] - 1s 94us/step - loss: 1.5532
# Epoch 46/50
# 8970/8970 [==============================] - 1s 97us/step - loss: 1.5508
# Epoch 47/50
# 8970/8970 [==============================] - 1s 94us/step - loss: 1.5516
# Epoch 48/50
# 8970/8970 [==============================] - 1s 100us/step - loss: 1.5515
# Epoch 49/50
# 8970/8970 [==============================] - 1s 94us/step - loss: 1.5505
# Epoch 50/50
# 8970/8970 [==============================] - 1s 94us/step - loss: 1.5509
# Generating from seed: ot
# ot( ot , th),( th , he),( he , e ),( e  ,  t),(  t , th),( th , he),( he , e ),( e  ,  t),(  t , th),( th , he),( he , e ),( e  ,  t),(  t , th),( th , he),( he , e ),( e  ,  t),(  t , th),( th , he),( he , e ),( e  ,  t),(  t , th),( th , he),( he , e ),( e  ,  t),(  t , th),

# %% [markdown]
# ## 1-char to 1 char loss: 2.1729

# %%
#	program to find next character given five characters using 
#	lstm by Santhosh on 19-7-18

#preparation of dataset

file=open('story.txt')
lines=list()
for line in file:
	line=line.strip().lower()
	line.encode("ascii","ignore")
	if len(line)==0:
		continue
	lines.append(line)
file.close()
text=" ".join(lines)

#generating a characters vocabulary,
chars=set([c for c in text]) 
nb_chars=len(chars)
char2index=	dict((c,i) for i,c in enumerate(chars))
index2char=	dict((i,c) for i,c in enumerate(chars))
print(nb_chars)

SEQLEN = 1
STEP = 1
input_chars = []
label_chars = []
for i in range(0, len(text) - SEQLEN, STEP):
	input_chars.append(text[i:i + SEQLEN])
	label_chars.append(text[i + SEQLEN])

#preparing training data
import numpy as np
x=np.zeros((len(input_chars),SEQLEN,nb_chars),dtype=np.bool)
y=np.zeros((len(input_chars),nb_chars),dtype=np.bool)
for i,input_char in enumerate(input_chars):
	for j,ch in enumerate(input_char):
		x[i,j,char2index[ch]]=1
	y[i,char2index[label_chars[i]]]=1

#preparing the model
from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential
HIDDEN_SIZE = 128

BATCH_SIZE = 128
NUM_ITERATIONS = 5
NUM_EPOCHS_PER_ITERATION = 50
NUM_PREDS_PER_EPOCH = 25

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
input_shape=(SEQLEN,nb_chars,)))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
model.summary()

for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1, SEQLEN, nb_chars))
        for i, ch in enumerate(test_chars):
            Xtest[0, i, char2index[ch]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print('(',test_chars,',',test_chars[1:] +ypred, end="),")
        # move forward with test_chars + ypred
        test_chars = test_chars[1:] + ypred
print()
# Out:
# 36
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 128)               84480
# _________________________________________________________________
# dense_3 (Dense)              (None, 36)                4644
# _________________________________________________________________
# activation_3 (Activation)    (None, 36)                0
# =================================================================
# Total params: 89,124
# Trainable params: 89,124
# Non-trainable params: 0
# _________________________________________________________________
# ==================================================
# Iteration #: 0
# Epoch 1/50
# 8971/8971 [==============================] - 1s 164us/step - loss: 3.4026
# Epoch 2/50
# 8971/8971 [==============================] - 1s 78us/step - loss: 2.9661
# Epoch 3/50
# 8971/8971 [==============================] - 1s 75us/step - loss: 2.6874
# Epoch 4/50
# 8971/8971 [==============================] - 1s 79us/step - loss: 2.5371
# Epoch 5/50
# 8971/8971 [==============================] - 1s 90us/step - loss: 2.4318
# Epoch 6/50
# 8971/8971 [==============================] - 1s 93us/step - loss: 2.3681
# Epoch 7/50
# 8971/8971 [==============================] - 1s 82us/step - loss: 2.3316
# Epoch 8/50
# 8971/8971 [==============================] - 1s 94us/step - loss: 2.3086
# Epoch 9/50
# 8971/8971 [==============================] - 1s 87us/step - loss: 2.2917
# Epoch 10/50
# 8971/8971 [==============================] - 1s 85us/step - loss: 2.2792
# Epoch 11/50
# 8971/8971 [==============================] - 1s 85us/step - loss: 2.2688
# Epoch 12/50
# 8971/8971 [==============================] - 1s 90us/step - loss: 2.2599
# Epoch 13/50
# 8971/8971 [==============================] - 1s 75us/step - loss: 2.2522
# Epoch 14/50
# 8971/8971 [==============================] - 1s 73us/step - loss: 2.2456
# Epoch 15/50
# 8971/8971 [==============================] - 1s 80us/step - loss: 2.2394
# Epoch 16/50
# 8971/8971 [==============================] - 1s 76us/step - loss: 2.2340
# Epoch 17/50
# 8971/8971 [==============================] - 1s 81us/step - loss: 2.2291
# Epoch 18/50
# 8971/8971 [==============================] - 1s 82us/step - loss: 2.2247
# Epoch 19/50
# 8971/8971 [==============================] - 1s 69us/step - loss: 2.2206
# Epoch 20/50
# 8971/8971 [==============================] - 1s 79us/step - loss: 2.2167
# Epoch 21/50
# 8971/8971 [==============================] - 1s 69us/step - loss: 2.2134
# Epoch 22/50
# 8971/8971 [==============================] - 1s 68us/step - loss: 2