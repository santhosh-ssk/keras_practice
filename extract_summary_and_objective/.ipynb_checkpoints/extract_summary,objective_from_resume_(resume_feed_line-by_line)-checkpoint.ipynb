# %% [markdown]
# # Sequence to Sequence model to extract summary,objective from resume (input: resume line by line)

# %% [markdown]
# # Trained data 40 resumes and 10 testing resumes to validate
#
# ## Example 1:
# ###             Input:
#
# ###           Output:

# %%
from __future__ import print_function
import csv,os
import collections
from keras.models import Model,load_model
from keras.layers import Input,LSTM,Dense
from keras.callbacks import ModelCheckpoint
import numpy as np

batch_size=90
epochs=25
latent_dim=128
data_path="/home/santhosh/resumes_folder/custom_annotator/annotator-server/static/files/Data_Tracter_Resumes_in_TXT/csv_1"
# Out:
# /home/santhosh/anaconda3/envs/pydl/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## vectorizing the data

# %%
input_resumes=[]
output_summary=[]
input_tokens=collections.Counter()
output_tokens=set()
files=os.listdir(data_path)
count=0
line=0;
for file in files:
    with open(data_path+'/'+file,'r') as csv_file:
        reader=csv.reader(csv_file)
        count=0
        for Input_text,output in reader:
            Input_text=Input_text.strip().lower()
            Input_text=Input_text+' \n'
            if(output=='1'):
                output_text=Input_text+' \n'
            else:
                output_text=""
            
            # We use "<SOL>" as the "start sequence" character
            # for the targets, and "<EOL>" as "end sequence" character.
            output_text='<SOL> '+output_text+' <EOL>'
            input_resumes.append(Input_text)
            output_summary.append(output_text)
            for word in Input_text.split():
                if word not in input_tokens:
                    input_tokens[word]+=1
            for word in output_text.split():
                if word not in output_tokens:
                    output_tokens.add(word)
            if count==40:
                break
            count+=1

# %%
print(len(input_tokens))
num_encoder_tokens=min(len(input_tokens),3500)
input_tokens=[word for word,count in input_tokens.most_common(num_encoder_tokens-1)]
input_tokens=sorted(list(input_tokens))
output_tokens=sorted(list(output_tokens))
num_decoder_tokens=len(output_tokens)
max_encoder_seq_len=max([len(text.split()) for text in input_resumes])
max_decoder_seq_len=max([len(text.split()) for text in output_summary])

print('Number of samples:',len(input_resumes))
print('number of unique input token:',num_encoder_tokens)
print('number of unique output token:',num_decoder_tokens)
print('Max Sequence length for inputs:',max_encoder_seq_len)
print('Max Sequence length for outputs:',max_decoder_seq_len)
# Out:
# 4221
# Number of samples: 2043
# number of unique input token: 3500
# number of unique output token: 1568
# Max Sequence length for inputs: 26
# Max Sequence length for outputs: 24

# %% [markdown]
# ## defining token2index

# %%
input_token2index=dict([(word,i) for i,word in enumerate(input_tokens)])
output_token2index=dict([(word,i) for i,word in enumerate(output_tokens)])
input_token2index['UNK']=num_encoder_tokens-1

# %% [markdown]
# ## defing encoder_input,decoder_input and decoder_output

# %%
encoder_input_data=np.zeros((len(input_resumes),max_encoder_seq_len,num_encoder_tokens),dtype='float32')
decoder_input_data=np.zeros((len(input_resumes),max_decoder_seq_len,num_decoder_tokens),dtype='float32')
decoder_target_data=np.zeros((len(input_resumes),max_decoder_seq_len,num_decoder_tokens),dtype='float32')

# %% [markdown]
# ## creating training dataset

# %%
for i,(input_text,target_text) in enumerate(zip(input_resumes,output_summary)):
    for t,word in enumerate(input_text.split()[:max_encoder_seq_len]):
        if word not in input_token2index:
            word="UNK"
        encoder_input_data[i,t,input_token2index[word]]=1
        
    for t,word in enumerate(target_text.split()):
        decoder_input_data[i,t,output_token2index[word]]=1
        # decoder_target_data is ahead of decoder_input_data by one timestep
        if t>0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i,t-1,output_token2index[word]]=1

# %% [markdown]
# ## Define an input sequence and process it.

# %%
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %% [markdown]
# ## Set up the decoder, using encoder_states as initial state.

# %%
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %% [markdown]
# ## Define the model that will turn
# ## `encoder_input_data` & `decoder_input_data` into `decoder_target_data`

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=["accuracy"])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, 3500)   0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 1568)   0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 128), (None, 1858048     input_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 128),  868864      input_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 1568)   202272      lstm_2[0][0]
# ==================================================================================================
# Total params: 2,929,184
# Trainable params: 2,929,184
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## function to test model

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_word_index = dict(
    (i, word) for word, i in input_token2index.items())
reverse_target_word_index = dict(
    (i, word) for word, i in output_token2index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, output_token2index['<SOL>']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = reverse_target_word_index[sampled_token_index]
        decoded_sentence += ' '+sampled_word

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_word == '<EOL>' or
           len(decoded_sentence.split()) > max_decoder_seq_len):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]
    if('<EOL>' in decoded_sentence):
        decoded_sentence=" ".join(decoded_sentence.split()[:-1])
    return decoded_sentence

# %% [markdown]
# ## Run training

# %%
iteration_file="/home/santhosh/resumes_folder/keras/extract_summary_and_objective/iteration_resume_line_level.txt"
iteration=0

# load weights
print('loading the weights')
model=load_model('resume_line_level.h5')

# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate([encoder_input_data, decoder_input_data], decoder_target_data,verbose=0)
print("%s: %.2f%%\n\n" % (model.metrics_names[1], scores[1]*100))
print("Testing Samples\n"+"-"*50)
print("-"*50)
index=int(np.random.randint(len(input_resumes)/40*0.8))
test_input=""
test_output=""
for i in range(40):
    encoded_input_sequence=(encoder_input_data[index]).reshape((1,max_encoder_seq_len,num_encoder_tokens))
    #print(encoded_input_sequence.shape,max_encoder_seq_len,num_encoder_tokens,max_encoder_seq_len*num_encoder_tokens)
    #print(encoded_input_sequence)
    #.reshape((1,max_encoder_seq_len,num_encoder_tokens))
    output_sequence=decode_sequence(encoded_input_sequence)
    test_input+=input_resumes[index]
    test_output+=output_sequence
    index+=1
print("-"*50)
print(test_input)
print("---OUTPUT-----")
print(test_output)
print(" "*50+"-"*50)
try:
    file=open(iteration_file,'r')
    last_line=file.read().split('\n')[-2]
    print('file_data,',last_line)
    iteration=int(last_line.split(':')[1])
    #print(iteration)
    file.close()
    
except:
    print('no file exist')

# checkpoint
filepath="resume_line_level_checkpoints.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

while True:
    print('Iteration:',iteration+1)
    #training
    model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,callbacks=callbacks_list)
    #prepare sample_data to test 5 samples:
    print("-"*50)
    index=int(np.random.randint(len(input_resumes)/40*0.8))
    test_input=""
    test_output=""
    for i in range(40):
        encoded_input_sequence=(encoder_input_data[index]).reshape((1,max_encoder_seq_len,num_encoder_tokens))
        #print(encoded_input_sequence.shape,max_encoder_seq_len,num_encoder_tokens,max_encoder_seq_len*num_encoder_tokens)
        #print(encoded_input_sequence)
        #.reshape((1,max_encoder_seq_len,num_encoder_tokens))
        output_sequence=decode_sequence(encoded_input_sequence)
        test_input+=input_resumes[index]
        test_output+=output_sequence
        index+=1
    print("-"*50)
    print(test_input)
    print("---OUTPUT-----")
    print(test_output)
    print(" "*50+"-"*50)
        
        
        
    # Save model
    file=open(iteration_file,'a')
    file.write('iteration:'+str(iteration+1)+'\n')
    file.close()
    iteration+=1
    model.save('resume_line_level.h5')
# Out:
# Iteration: 1
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 77s 47ms/step - loss: 0.8411 - acc: 0.0391 - val_loss: 0.6863 - val_acc: 0.0417
# /home/santhosh/anaconda3/envs/pydl/lib/python3.5/site-packages/keras/engine/network.py:888: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1/while/Exit_2:0' shape=(?, 128) dtype=float32>, <tf.Tensor 'lstm_1/while/Exit_3:0' shape=(?, 128) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# Epoch 2/25
# 1634/1634 [==============================] - 74s 45ms/step - loss: 0.6971 - acc: 0.0417 - val_loss: 0.6910 - val_acc: 0.0417
# Epoch 3/25
# 1634/1634 [==============================] - 67s 41ms/step - loss: 0.6858 - acc: 0.0417 - val_loss: 0.6950 - val_acc: 0.0417
# Epoch 4/25
# 1634/1634 [==============================] - 60s 37ms/step - loss: 0.6793 - acc: 0.0417 - val_loss: 0.7093 - val_acc: 0.0417
# Epoch 5/25
# 1634/1634 [==============================] - 62s 38ms/step - loss: 0.6760 - acc: 0.0417 - val_loss: 0.7184 - val_acc: 0.0417
# Epoch 6/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.6686 - acc: 0.0417 - val_loss: 0.7256 - val_acc: 0.0417
# Epoch 7/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6650 - acc: 0.0417 - val_loss: 0.7445 - val_acc: 0.0418
# Epoch 8/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.6605 - acc: 0.0417 - val_loss: 0.7419 - val_acc: 0.0417
# Epoch 9/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6548 - acc: 0.0418 - val_loss: 0.7708 - val_acc: 0.0424
# Epoch 10/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6502 - acc: 0.0426 - val_loss: 0.7444 - val_acc: 0.0423
# Epoch 11/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.6430 - acc: 0.0435 - val_loss: 0.7403 - val_acc: 0.0427
# Epoch 12/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6369 - acc: 0.0438 - val_loss: 0.7667 - val_acc: 0.0430
# Epoch 13/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.6310 - acc: 0.0443 - val_loss: 0.7572 - val_acc: 0.0331
# Epoch 14/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6235 - acc: 0.0452 - val_loss: 0.7492 - val_acc: 0.0391
# Epoch 15/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6209 - acc: 0.0454 - val_loss: 0.7585 - val_acc: 0.0349
# Epoch 16/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.6141 - acc: 0.0458 - val_loss: 0.7622 - val_acc: 0.0341
# Epoch 17/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6087 - acc: 0.0462 - val_loss: 0.7639 - val_acc: 0.0383
# Epoch 18/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.6062 - acc: 0.0462 - val_loss: 0.7622 - val_acc: 0.0413
# Epoch 19/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.6020 - acc: 0.0466 - val_loss: 0.7659 - val_acc: 0.0394
# Epoch 20/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.5992 - acc: 0.0467 - val_loss: 0.7561 - val_acc: 0.0416
# Epoch 21/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.5930 - acc: 0.0468 - val_loss: 0.7613 - val_acc: 0.0406
# Epoch 22/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.5873 - acc: 0.0476 - val_loss: 0.7726 - val_acc: 0.0401
# Epoch 23/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.5846 - acc: 0.0474 - val_loss: 0.7598 - val_acc: 0.0400
# Epoch 24/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5811 - acc: 0.0476 - val_loss: 0.7670 - val_acc: 0.0411
# Epoch 25/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5746 - acc: 0.0475 - val_loss: 0.7717 - val_acc: 0.0420
# --------------------------------------------------
# --------------------------------------------------
#  good knowledge of unix.
#  good interpersonal skills & learn new technologies and undertake challenges.
# academic credentials:
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
# tools/technologies web-cruiser , havij, tortoisesvn, jmeter, jenkins
#
# abhishek appanna kalagoudra
# 7#b/4, nav annapurna arti bldg, annapurna nagar, mobile: 9820385126
# adharwadi, kalyan(w).maharashtra-421301. email:abhishek.kalagoudra@gmail.com
# objective:
# want to work and implement my knowledge in an it organization to accomplish
# organizational goals and upgrade my knowledge.
# summary:
#  more than 3 years 7 months of software development experience.
#  got chance to join a start-up and be the first employee of the company to work with
# close connection to the highly experienced players in it industry.
#  have knowledge in objective c , c#, asp.net, xml, c++.
#  master of computer application from pune university.
#  strong analytical skills and experience in developing optimized, high performance
# systems.
#  experience in developing applications for iphone and ipad devices.
#  trained a fresher for iphone development.
#  knowledge in developing web based application and sites.
# experience:
#  aurality
# designation : software enginner
# platform : objective c (iphone), asp.net c# razor
# duration : june 2011 to till date
# description : aurality is a product based seed funded startup, where i got a
# lead role to handle the client side application development(iphone) with close connection
# to highly experienced players in the it industry. aurality is like a radio which reads out
# the content like blog and news feeds for you. now aurality has pivoted from its iphone
# application to a gifting site called giftery. before starting with giftery i was into product
# research and later the idea of giftery was brought into picture.
#
# ---OUTPUT-----
#  experience in in of and and and and good in in and and and and and good in in and and and and and and and and and and good in in and and and and and and and and and and good in in and and and and and good in in and and and and and good in in and and and and and good in in and and and and good in in and and and and and
#                                                   --------------------------------------------------
# Iteration: 2
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5711 - acc: 0.0481 - val_loss: 0.7715 - val_acc: 0.0414
# Epoch 2/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5667 - acc: 0.0487 - val_loss: 0.7657 - val_acc: 0.0391
# Epoch 3/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5626 - acc: 0.0484 - val_loss: 0.7605 - val_acc: 0.0405
# Epoch 4/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.5589 - acc: 0.0487 - val_loss: 0.7644 - val_acc: 0.0415
# Epoch 5/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5524 - acc: 0.0494 - val_loss: 0.7538 - val_acc: 0.0400
# Epoch 6/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.5483 - acc: 0.0500 - val_loss: 0.7652 - val_acc: 0.0401
# Epoch 7/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.5453 - acc: 0.0500 - val_loss: 0.7514 - val_acc: 0.0387
# Epoch 8/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.5416 - acc: 0.0500 - val_loss: 0.7635 - val_acc: 0.0390
# Epoch 9/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.5358 - acc: 0.0507 - val_loss: 0.7830 - val_acc: 0.0425
# Epoch 10/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.5315 - acc: 0.0509 - val_loss: 0.7528 - val_acc: 0.0392
# Epoch 11/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5284 - acc: 0.0509 - val_loss: 0.7600 - val_acc: 0.0328
# Epoch 12/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5222 - acc: 0.0513 - val_loss: 0.7659 - val_acc: 0.0284
# Epoch 13/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5223 - acc: 0.0513 - val_loss: 0.7508 - val_acc: 0.0401
# Epoch 14/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.5144 - acc: 0.0517 - val_loss: 0.7626 - val_acc: 0.0405
# Epoch 15/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.5107 - acc: 0.0518 - val_loss: 0.7519 - val_acc: 0.0407
# Epoch 16/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5056 - acc: 0.0519 - val_loss: 0.7695 - val_acc: 0.0412
# Epoch 17/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.5035 - acc: 0.0521 - val_loss: 0.7506 - val_acc: 0.0370
# Epoch 18/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.4969 - acc: 0.0530 - val_loss: 0.7477 - val_acc: 0.0400
# Epoch 19/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.4943 - acc: 0.0527 - val_loss: 0.7655 - val_acc: 0.0400
# Epoch 20/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.4891 - acc: 0.0529 - val_loss: 0.7493 - val_acc: 0.0378
# Epoch 21/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4870 - acc: 0.0531 - val_loss: 0.7498 - val_acc: 0.0412
# Epoch 22/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.4794 - acc: 0.0534 - val_loss: 0.7440 - val_acc: 0.0403
# Epoch 23/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.4765 - acc: 0.0540 - val_loss: 0.7620 - val_acc: 0.0412
# Epoch 24/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.4711 - acc: 0.0544 - val_loss: 0.7494 - val_acc: 0.0413
# Epoch 25/25
# 1634/1634 [==============================] - 74s 45ms/step - loss: 0.4705 - acc: 0.0542 - val_loss: 0.7431 - val_acc: 0.0413
# --------------------------------------------------
# --------------------------------------------------
# career objective:
# a result oriented professional who can work in a fast paced work environment and able to deliver on time
# and with quality. quick learner and enjoys being a part of a successful and productive team as well
# possess a strong ability to perform individually.
# experience summary:
#  3.5 + year of total experience in software testing and quality assurance.
#  clear understanding of software development life cycle models (sdlc) and software testing
# life cycle (stlc).
#  involved in understanding and analysis of requirement (srs) document.
#  involved in the writing and execution of the test cases using test-link, ms -excel based on
# business requirement and technical specifications and logging the defect in the bugzilla,
# jira.
#  experience of testing web based application.
#  experience of automating ui using robot framework with selenium library
#  experience of testing web application and database with algolia search engine
#  experience of testing api using rest client
#  experience of automating api using robot framework
#  thorough knowledge of software testing methodologies including functional, retesting,
# regression, browser compatibility, integration, and gui and negative testing of an
# application.
#  knowledge about software quality assurance, and agile methodology.
#  expertise in resolving bugs and issues with developers.
#  knowledge of using tortoisesvn & git
#  involved in deployment of test builds & automating it using jenkins.
#  involved in writing of sql queries.
#  good knowledge of unix.
#  good interpersonal skills & learn new technologies and undertake challenges.
# academic credentials:
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
# tools/technologies web-cruiser , havij, tortoisesvn, jmeter, jenkins
#
# abhishek appanna kalagoudra
# 7#b/4, nav annapurna arti bldg, annapurna nagar, mobile: 9820385126
# adharwadi, kalyan(w).maharashtra-421301. email:abhishek.kalagoudra@gmail.com
#
# ---OUTPUT-----
#  to a a a a a a to to to to to to aand to a a a a a a a to to to to to aand to a a a a a a a to to to to to a experience in experience in the and and and experience in experience in and and andand to to a a a a a a a to the to to a experience in experience in the and and and experience in experience in the and and andand to a a a a a a a to to to to to a experience in experience in the and and and experience in experience in and and and experience in experience in and and and experience in experience in and and and experience in experience in and and and experience in experience in the and and andand to to a a a a a a a a a a a experience in experience in and and and experience in experience in and and and experience in in and and and skills experience in experience in the and and and experience in experience in the and and and experience in experience in and and and experience in in and and and
#                                                   --------------------------------------------------
# Iteration: 3
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4621 - acc: 0.0550 - val_loss: 0.7408 - val_acc: 0.0407
# Epoch 2/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4577 - acc: 0.0555 - val_loss: 0.7521 - val_acc: 0.0349
# Epoch 3/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.4527 - acc: 0.0558 - val_loss: 0.7601 - val_acc: 0.0378
# Epoch 4/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4523 - acc: 0.0561 - val_loss: 0.7459 - val_acc: 0.0424
# Epoch 5/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4460 - acc: 0.0571 - val_loss: 0.7436 - val_acc: 0.0417
# Epoch 6/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4391 - acc: 0.0576 - val_loss: 0.7459 - val_acc: 0.0412
# Epoch 7/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4374 - acc: 0.0575 - val_loss: 0.7439 - val_acc: 0.0421
# Epoch 8/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.4313 - acc: 0.0580 - val_loss: 0.7533 - val_acc: 0.0382
# Epoch 9/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4267 - acc: 0.0585 - val_loss: 0.7417 - val_acc: 0.0418
# Epoch 10/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.4201 - acc: 0.0595 - val_loss: 0.7496 - val_acc: 0.0414
# Epoch 11/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4177 - acc: 0.0592 - val_loss: 0.7463 - val_acc: 0.0419
# Epoch 12/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.4128 - acc: 0.0600 - val_loss: 0.7455 - val_acc: 0.0423
# Epoch 13/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4069 - acc: 0.0605 - val_loss: 0.7479 - val_acc: 0.0435
# Epoch 14/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.4035 - acc: 0.0611 - val_loss: 0.7459 - val_acc: 0.0398
# Epoch 15/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3974 - acc: 0.0618 - val_loss: 0.7483 - val_acc: 0.0437
# Epoch 16/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3923 - acc: 0.0623 - val_loss: 0.7419 - val_acc: 0.0432
# Epoch 17/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.3892 - acc: 0.0626 - val_loss: 0.7507 - val_acc: 0.0412
# Epoch 18/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3857 - acc: 0.0634 - val_loss: 0.7437 - val_acc: 0.0435
# Epoch 19/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3772 - acc: 0.0636 - val_loss: 0.7399 - val_acc: 0.0436
# Epoch 20/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3748 - acc: 0.0647 - val_loss: 0.7566 - val_acc: 0.0424
# Epoch 21/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3696 - acc: 0.0644 - val_loss: 0.7339 - val_acc: 0.0439
# Epoch 22/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.3629 - acc: 0.0660 - val_loss: 0.7451 - val_acc: 0.0452
# Epoch 23/25
# 1634/1634 [==============================] - 71s 44ms/step - loss: 0.3600 - acc: 0.0667 - val_loss: 0.7458 - val_acc: 0.0440
# Epoch 24/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3554 - acc: 0.0670 - val_loss: 0.7378 - val_acc: 0.0431
# Epoch 25/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3498 - acc: 0.0679 - val_loss: 0.7494 - val_acc: 0.0443
# --------------------------------------------------
# --------------------------------------------------
# resume
# name – abhijeet kudale.
# contact no – +91-9960819797
# email – abhijeet.kudale567@gmail.com
# total it experience – 3.5 + year of experience in software testing
# career objective:
# a result oriented professional who can work in a fast paced work environment and able to deliver on time
# and with quality. quick learner and enjoys being a part of a successful and productive team as well
# possess a strong ability to perform individually.
# experience summary:
#  3.5 + year of total experience in software testing and quality assurance.
#  clear understanding of software development life cycle models (sdlc) and software testing
# life cycle (stlc).
#  involved in understanding and analysis of requirement (srs) document.
#  involved in the writing and execution of the test cases using test-link, ms -excel based on
# business requirement and technical specifications and logging the defect in the bugzilla,
# jira.
#  experience of testing web based application.
#  experience of automating ui using robot framework with selenium library
#  experience of testing web application and database with algolia search engine
#  experience of testing api using rest client
#  experience of automating api using robot framework
#  thorough knowledge of software testing methodologies including functional, retesting,
# regression, browser compatibility, integration, and gui and negative testing of an
# application.
#  knowledge about software quality assurance, and agile methodology.
#  expertise in resolving bugs and issues with developers.
#  knowledge of using tortoisesvn & git
#  involved in deployment of test builds & automating it using jenkins.
#  involved in writing of sql queries.
#  good knowledge of unix.
#  good interpersonal skills & learn new technologies and undertake challenges.
# academic credentials:
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
#
# ---OUTPUT-----
# to to a a challenging in challenging and challenging and my my my my and to to a a a challenging in challenging and challenging and my my and a a a a a a a a a aand to a a a a a player in a work and work to a a a a a a a a a a experience in the phases of sdlc development and using using good knowledge of web and and algorithms. and data good knowledge of experience in product and experience in the and and of of of using and to to a a a in a challenging and challenging and my my and a a a a a a a a a a good knowledge of experience in robot and good knowledge of experience in robot and good knowledge of web and and algorithms. good knowledge of experience in robot and good knowledge of web and and algorithms. good knowledge of web and and algorithms.development, and to to a a a in in in challenging and the my and good knowledge of web and and algorithms. good knowledge of web and and algorithms. good knowledge of web and experience in the and and like of of using good knowledge of experience in robot and good knowledge of web and good knowledge of web and
#                                                   --------------------------------------------------
# Iteration: 4
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.3455 - acc: 0.0687 - val_loss: 0.7357 - val_acc: 0.0469
# Epoch 2/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.3401 - acc: 0.0692 - val_loss: 0.7456 - val_acc: 0.0435
# Epoch 3/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3334 - acc: 0.0701 - val_loss: 0.7426 - val_acc: 0.0451
# Epoch 4/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3290 - acc: 0.0715 - val_loss: 0.7455 - val_acc: 0.0440
# Epoch 5/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.3263 - acc: 0.0714 - val_loss: 0.7375 - val_acc: 0.0448
# Epoch 6/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3189 - acc: 0.0726 - val_loss: 0.7421 - val_acc: 0.0454
# Epoch 7/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3179 - acc: 0.0738 - val_loss: 0.7317 - val_acc: 0.0476
# Epoch 8/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.3118 - acc: 0.0752 - val_loss: 0.7445 - val_acc: 0.0463
# Epoch 9/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.3079 - acc: 0.0751 - val_loss: 0.7333 - val_acc: 0.0472
# Epoch 10/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.3002 - acc: 0.0773 - val_loss: 0.7467 - val_acc: 0.0478
# Epoch 11/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2971 - acc: 0.0778 - val_loss: 0.7454 - val_acc: 0.0469
# Epoch 12/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.2930 - acc: 0.0789 - val_loss: 0.7392 - val_acc: 0.0467
# Epoch 13/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.2883 - acc: 0.0810 - val_loss: 0.7651 - val_acc: 0.0428
# Epoch 14/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2856 - acc: 0.0810 - val_loss: 0.7393 - val_acc: 0.0480
# Epoch 15/25
# 1634/1634 [==============================] - 74s 45ms/step - loss: 0.2790 - acc: 0.0823 - val_loss: 0.7425 - val_acc: 0.0460
# Epoch 16/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2746 - acc: 0.0835 - val_loss: 0.7409 - val_acc: 0.0480
# Epoch 17/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2701 - acc: 0.0845 - val_loss: 0.7433 - val_acc: 0.0465
# Epoch 18/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.2662 - acc: 0.0857 - val_loss: 0.7452 - val_acc: 0.0480
# Epoch 19/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2652 - acc: 0.0858 - val_loss: 0.7398 - val_acc: 0.0485
# Epoch 20/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2574 - acc: 0.0884 - val_loss: 0.7458 - val_acc: 0.0478
# Epoch 21/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2544 - acc: 0.0892 - val_loss: 0.7329 - val_acc: 0.0512
# Epoch 22/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.2496 - acc: 0.0900 - val_loss: 0.7414 - val_acc: 0.0504
# Epoch 23/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.2445 - acc: 0.0914 - val_loss: 0.7373 - val_acc: 0.0508
# Epoch 24/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2415 - acc: 0.0936 - val_loss: 0.7340 - val_acc: 0.0498
# Epoch 25/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.2346 - acc: 0.0946 - val_loss: 0.7555 - val_acc: 0.0451
# --------------------------------------------------
# --------------------------------------------------
#  good interpersonal skills & learn new technologies and undertake challenges.
# academic credentials:
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
# tools/technologies web-cruiser , havij, tortoisesvn, jmeter, jenkins
#
# abhishek appanna kalagoudra
# 7#b/4, nav annapurna arti bldg, annapurna nagar, mobile: 9820385126
# adharwadi, kalyan(w).maharashtra-421301. email:abhishek.kalagoudra@gmail.com
# objective:
# want to work and implement my knowledge in an it organization to accomplish
# organizational goals and upgrade my knowledge.
# summary:
#  more than 3 years 7 months of software development experience.
#  got chance to join a start-up and be the first employee of the company to work with
# close connection to the highly experienced players in it industry.
#  have knowledge in objective c , c#, asp.net, xml, c++.
#  master of computer application from pune university.
#  strong analytical skills and experience in developing optimized, high performance
# systems.
#  experience in developing applications for iphone and ipad devices.
#  trained a fresher for iphone development.
#  knowledge in developing web based application and sites.
# experience:
#  aurality
# designation : software enginner
# platform : objective c (iphone), asp.net c# razor
# duration : june 2011 to till date
# description : aurality is a product based seed funded startup, where i got a
# lead role to handle the client side application development(iphone) with close connection
# to highly experienced players in the it industry. aurality is like a radio which reads out
# the content like blog and news feeds for you. now aurality has pivoted from its iphone
# application to a gifting site called giftery. before starting with giftery i was into product
# research and later the idea of giftery was brought into picture.
#  powerweave
#
# ---OUTPUT-----
#  good knowledge of experience in robot and have years of experience in software development and software development andto a a position in a challenging and challenging and my my my abilitiesdevelopment, testing, and implementation have years of experience in software development and software development and have years of experience in software development and software development anddevelopment, to to a a a a challenging and the abilities and the abilitiesdevelopment, testing, and implementation and timely delivery delivery against have years of experience in software development and software development and software to a position and a growth. good knowledge of cloud and controls, good knowledge of experience in product anddevelopment, and implementation of support. good knowledge of cloud web and ajax
#                                                   --------------------------------------------------
# Iteration: 5
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.2355 - acc: 0.0938 - val_loss: 0.7411 - val_acc: 0.0487
# Epoch 2/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.2274 - acc: 0.0967 - val_loss: 0.7387 - val_acc: 0.0486
# Epoch 3/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2255 - acc: 0.0967 - val_loss: 0.7280 - val_acc: 0.0491
# Epoch 4/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.2218 - acc: 0.0984 - val_loss: 0.7464 - val_acc: 0.0482
# Epoch 5/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2173 - acc: 0.0992 - val_loss: 0.7476 - val_acc: 0.0497
# Epoch 6/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.2130 - acc: 0.0997 - val_loss: 0.7341 - val_acc: 0.0522
# Epoch 7/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2110 - acc: 0.1004 - val_loss: 0.7460 - val_acc: 0.0488
# Epoch 8/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.2049 - acc: 0.1024 - val_loss: 0.7368 - val_acc: 0.0506
# Epoch 9/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.2005 - acc: 0.1031 - val_loss: 0.7407 - val_acc: 0.0498
# Epoch 10/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1997 - acc: 0.1039 - val_loss: 0.7449 - val_acc: 0.0508
# Epoch 11/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1957 - acc: 0.1042 - val_loss: 0.7440 - val_acc: 0.0507
# Epoch 12/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1928 - acc: 0.1051 - val_loss: 0.7502 - val_acc: 0.0482
# Epoch 13/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1863 - acc: 0.1070 - val_loss: 0.7565 - val_acc: 0.0486
# Epoch 14/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1840 - acc: 0.1076 - val_loss: 0.7503 - val_acc: 0.0502
# Epoch 15/25
# 1634/1634 [==============================] - 71s 44ms/step - loss: 0.1826 - acc: 0.1072 - val_loss: 0.7409 - val_acc: 0.0531
# Epoch 16/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1781 - acc: 0.1089 - val_loss: 0.7493 - val_acc: 0.0504
# Epoch 17/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1725 - acc: 0.1095 - val_loss: 0.7495 - val_acc: 0.0508
# Epoch 18/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1729 - acc: 0.1104 - val_loss: 0.7514 - val_acc: 0.0517
# Epoch 19/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1689 - acc: 0.1110 - val_loss: 0.7455 - val_acc: 0.0515
# Epoch 20/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1637 - acc: 0.1125 - val_loss: 0.7465 - val_acc: 0.0514
# Epoch 21/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1625 - acc: 0.1125 - val_loss: 0.7470 - val_acc: 0.0509
# Epoch 22/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1594 - acc: 0.1132 - val_loss: 0.7525 - val_acc: 0.0526
# Epoch 23/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1556 - acc: 0.1143 - val_loss: 0.7491 - val_acc: 0.0514
# Epoch 24/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.1535 - acc: 0.1149 - val_loss: 0.7490 - val_acc: 0.0524
# Epoch 25/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1506 - acc: 0.1156 - val_loss: 0.7582 - val_acc: 0.0513
# --------------------------------------------------
# --------------------------------------------------
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
# tools/technologies web-cruiser , havij, tortoisesvn, jmeter, jenkins
#
# abhishek appanna kalagoudra
# 7#b/4, nav annapurna arti bldg, annapurna nagar, mobile: 9820385126
# adharwadi, kalyan(w).maharashtra-421301. email:abhishek.kalagoudra@gmail.com
# objective:
# want to work and implement my knowledge in an it organization to accomplish
# organizational goals and upgrade my knowledge.
# summary:
#  more than 3 years 7 months of software development experience.
#  got chance to join a start-up and be the first employee of the company to work with
# close connection to the highly experienced players in it industry.
#  have knowledge in objective c , c#, asp.net, xml, c++.
#  master of computer application from pune university.
#  strong analytical skills and experience in developing optimized, high performance
# systems.
#  experience in developing applications for iphone and ipad devices.
#  trained a fresher for iphone development.
#  knowledge in developing web based application and sites.
# experience:
#  aurality
# designation : software enginner
# platform : objective c (iphone), asp.net c# razor
# duration : june 2011 to till date
# description : aurality is a product based seed funded startup, where i got a
# lead role to handle the client side application development(iphone) with close connection
# to highly experienced players in the it industry. aurality is like a radio which reads out
# the content like blog and news feeds for you. now aurality has pivoted from its iphone
# application to a gifting site called giftery. before starting with giftery i was into product
# research and later the idea of giftery was brought into picture.
#  powerweave
# designation : software developer
# platform : objective c (iphone)
# duration : august 2010 to june 2011
# description : powerweave is majorly into artwork and a service based industry.
# here i got chance to start their mobile application division for iphone. and also trained a
# fresher for iphone development.
#  i knowledge factory
# designation : software developer
#
# ---OUTPUT-----
# career objectiveto a a position in a challenging and rewarding which my abilities and abilitiesand scada software.summaryprofessional summaryto pursue a a career in a challenging and rewarding environment to the best myutilized fully, there by improving myself along with the organization.experience summary: good knowledge of product web good knowledge of product and structures,databases,algorithms,python,cudac ,parallel computing,ivr programming ,strong good knowledge of product applications and algorithms. good knowledge of product applications good knowledge of data web and ajax
#                                                   --------------------------------------------------
# Iteration: 6
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1452 - acc: 0.1165 - val_loss: 0.7541 - val_acc: 0.0512
# Epoch 2/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.1461 - acc: 0.1161 - val_loss: 0.7590 - val_acc: 0.0491
# Epoch 3/25
# 1634/1634 [==============================] - 72s 44ms/step - loss: 0.1407 - acc: 0.1175 - val_loss: 0.7543 - val_acc: 0.0506
# Epoch 4/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1377 - acc: 0.1178 - val_loss: 0.7563 - val_acc: 0.0541
# Epoch 5/25
# 1634/1634 [==============================] - 73s 45ms/step - loss: 0.1367 - acc: 0.1180 - val_loss: 0.7511 - val_acc: 0.0526
# Epoch 6/25
# 1634/1634 [==============================] - 73s 44ms/step - loss: 0.1336 - acc: 0.1191 - val_loss: 0.7599 - val_acc: 0.0502
# Epoch 7/25
# 1634/1634 [==============================] - 58s 36ms/step - loss: 0.1333 - acc: 0.1192 - val_loss: 0.7527 - val_acc: 0.0522
# Epoch 8/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1270 - acc: 0.1204 - val_loss: 0.7840 - val_acc: 0.0487
# Epoch 9/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1274 - acc: 0.1201 - val_loss: 0.7587 - val_acc: 0.0552
# Epoch 10/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1223 - acc: 0.1220 - val_loss: 0.7609 - val_acc: 0.0509
# Epoch 11/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1222 - acc: 0.1216 - val_loss: 0.7607 - val_acc: 0.0532
# Epoch 12/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1181 - acc: 0.1229 - val_loss: 0.7628 - val_acc: 0.0509
# Epoch 13/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1169 - acc: 0.1225 - val_loss: 0.7608 - val_acc: 0.0523
# Epoch 14/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1140 - acc: 0.1240 - val_loss: 0.7659 - val_acc: 0.0522
# Epoch 15/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1111 - acc: 0.1235 - val_loss: 0.7586 - val_acc: 0.0529
# Epoch 16/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1115 - acc: 0.1235 - val_loss: 0.7637 - val_acc: 0.0515
# Epoch 17/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1064 - acc: 0.1254 - val_loss: 0.7565 - val_acc: 0.0542
# Epoch 18/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1084 - acc: 0.1243 - val_loss: 0.7574 - val_acc: 0.0572
# Epoch 19/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1022 - acc: 0.1270 - val_loss: 0.7655 - val_acc: 0.0531
# Epoch 20/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1034 - acc: 0.1259 - val_loss: 0.8075 - val_acc: 0.0406
# Epoch 21/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.1030 - acc: 0.1247 - val_loss: 0.7651 - val_acc: 0.0522
# Epoch 22/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0998 - acc: 0.1254 - val_loss: 0.7656 - val_acc: 0.0515
# Epoch 23/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0940 - acc: 0.1270 - val_loss: 0.7749 - val_acc: 0.0519
# Epoch 24/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0942 - acc: 0.1286 - val_loss: 0.7634 - val_acc: 0.0544
# Epoch 25/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0969 - acc: 0.1270 - val_loss: 0.7756 - val_acc: 0.0544
# --------------------------------------------------
# --------------------------------------------------
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
# tools/technologies web-cruiser , havij, tortoisesvn, jmeter, jenkins
#
# abhishek appanna kalagoudra
# 7#b/4, nav annapurna arti bldg, annapurna nagar, mobile: 9820385126
# adharwadi, kalyan(w).maharashtra-421301. email:abhishek.kalagoudra@gmail.com
# objective:
# want to work and implement my knowledge in an it organization to accomplish
# organizational goals and upgrade my knowledge.
# summary:
#  more than 3 years 7 months of software development experience.
#  got chance to join a start-up and be the first employee of the company to work with
# close connection to the highly experienced players in it industry.
#  have knowledge in objective c , c#, asp.net, xml, c++.
#  master of computer application from pune university.
#  strong analytical skills and experience in developing optimized, high performance
# systems.
#  experience in developing applications for iphone and ipad devices.
#  trained a fresher for iphone development.
#  knowledge in developing web based application and sites.
# experience:
#  aurality
# designation : software enginner
# platform : objective c (iphone), asp.net c# razor
# duration : june 2011 to till date
# description : aurality is a product based seed funded startup, where i got a
# lead role to handle the client side application development(iphone) with close connection
# to highly experienced players in the it industry. aurality is like a radio which reads out
# the content like blog and news feeds for you. now aurality has pivoted from its iphone
# application to a gifting site called giftery. before starting with giftery i was into product
# research and later the idea of giftery was brought into picture.
#  powerweave
# designation : software developer
# platform : objective c (iphone)
#
# ---OUTPUT-----
# objective:to a position in a challenging and rewarding that career career professionaldevelopment, testing, implementation and support.objectiveprofessional summary:to pursue my a career in a challenging and rewarding environment and to put my best effortsutilized fully, there by improving myself along with the organization.professional summary: good knowledge of data structures and algorithms. good knowledge of troubleshooting and fixing enthusiastic good knowledge of product and data handling. to a position and deliver. good analytical & troubleshooting and problem solving skills and good team player.
#                                                   --------------------------------------------------
# Iteration: 7
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0898 - acc: 0.1284 - val_loss: 0.7689 - val_acc: 0.0547
# Epoch 2/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0882 - acc: 0.1298 - val_loss: 0.7670 - val_acc: 0.0558
# Epoch 3/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0857 - acc: 0.1406 - val_loss: 0.7794 - val_acc: 0.0537
# Epoch 4/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0879 - acc: 0.1304 - val_loss: 0.7695 - val_acc: 0.0546
# Epoch 5/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0835 - acc: 0.1333 - val_loss: 0.7751 - val_acc: 0.0567
# Epoch 6/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0849 - acc: 0.1305 - val_loss: 0.7766 - val_acc: 0.0537
# Epoch 7/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0802 - acc: 0.1333 - val_loss: 0.7785 - val_acc: 0.0517
# Epoch 8/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0801 - acc: 0.1308 - val_loss: 0.7780 - val_acc: 0.0538
# Epoch 9/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0777 - acc: 0.1326 - val_loss: 0.7718 - val_acc: 0.0560
# Epoch 10/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0781 - acc: 0.1362 - val_loss: 0.7853 - val_acc: 0.0520
# Epoch 11/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0740 - acc: 0.1400 - val_loss: 0.7792 - val_acc: 0.0542
# Epoch 12/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0733 - acc: 0.1381 - val_loss: 0.7853 - val_acc: 0.0527
# Epoch 13/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0715 - acc: 0.1333 - val_loss: 0.7738 - val_acc: 0.0537
# Epoch 14/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0720 - acc: 0.1348 - val_loss: 0.7773 - val_acc: 0.0570
# Epoch 15/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0711 - acc: 0.1326 - val_loss: 0.7745 - val_acc: 0.0530
# Epoch 16/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0672 - acc: 0.1326 - val_loss: 0.7864 - val_acc: 0.0534
# Epoch 17/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0649 - acc: 0.1350 - val_loss: 0.7903 - val_acc: 0.0510
# Epoch 18/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0659 - acc: 0.1318 - val_loss: 0.7850 - val_acc: 0.0549
# Epoch 19/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0657 - acc: 0.1330 - val_loss: 0.7872 - val_acc: 0.0626
# Epoch 20/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0621 - acc: 0.1385 - val_loss: 0.7831 - val_acc: 0.0543
# Epoch 21/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0624 - acc: 0.1395 - val_loss: 0.7845 - val_acc: 0.0550
# Epoch 22/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0603 - acc: 0.1400 - val_loss: 0.7908 - val_acc: 0.0660
# Epoch 23/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0623 - acc: 0.1384 - val_loss: 0.7879 - val_acc: 0.0537
# Epoch 24/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0571 - acc: 0.1420 - val_loss: 0.8042 - val_acc: 0.0502
# Epoch 25/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0561 - acc: 0.1360 - val_loss: 0.7907 - val_acc: 0.0541
# --------------------------------------------------
# --------------------------------------------------
# resume
# name – abhijeet kudale.
# contact no – +91-9960819797
# email – abhijeet.kudale567@gmail.com
# total it experience – 3.5 + year of experience in software testing
# career objective:
# a result oriented professional who can work in a fast paced work environment and able to deliver on time
# and with quality. quick learner and enjoys being a part of a successful and productive team as well
# possess a strong ability to perform individually.
# experience summary:
#  3.5 + year of total experience in software testing and quality assurance.
#  clear understanding of software development life cycle models (sdlc) and software testing
# life cycle (stlc).
#  involved in understanding and analysis of requirement (srs) document.
#  involved in the writing and execution of the test cases using test-link, ms -excel based on
# business requirement and technical specifications and logging the defect in the bugzilla,
# jira.
#  experience of testing web based application.
#  experience of automating ui using robot framework with selenium library
#  experience of testing web application and database with algolia search engine
#  experience of testing api using rest client
#  experience of automating api using robot framework
#  thorough knowledge of software testing methodologies including functional, retesting,
# regression, browser compatibility, integration, and gui and negative testing of an
# application.
#  knowledge about software quality assurance, and agile methodology.
#  expertise in resolving bugs and issues with developers.
#  knowledge of using tortoisesvn & git
#  involved in deployment of test builds & automating it using jenkins.
#  involved in writing of sql queries.
#  good knowledge of unix.
#  good interpersonal skills & learn new technologies and undertake challenges.
# academic credentials:
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
#
# ---OUTPUT-----
# career objective:to work in learning and challenging environment, utilizing my skill and knowledge to the best of my abilities anddevelopment and systems on j2ee and dot net. a self-motivator and a passionate team player.experience summary: 3.5 + year of total experience in software testing and quality assurance. knowledge of software testing methodologies and functional, retesting,life cycle (stlc). involved in understanding and analysis of requirement (srs) document. involved in the writing and execution of the test cases using test-link, ms -excel based ondevelopment on requirement gathering, designing, designing, coding, testing, debugging and maintenance.french. experience of testing web based application. experience of automating ui using robot framework with selenium library experience of testing web based application. experience of automating api using robot framework experience of automating api using robot framework knowledge of software testing methodologies including functional, retesting,we practice scrum meeting, sprints knowledge of jira, p.tracker tools. knowledge about software quality assurance, and agile methodology. involved in writing technical blogs, have many blogs published already. knowledge of software testing methodologies and functional, retesting, involved in the writing and execution of the test cases using test-link, ms -excel based on involved in writing and fixing defects and the working on change requests (cr) good knowledge of unix. good team player with good communicative skills with ability to meet time new new
#                                                   --------------------------------------------------
# Iteration: 8
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0554 - acc: 0.1339 - val_loss: 0.7949 - val_acc: 0.0531
# Epoch 2/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0563 - acc: 0.1351 - val_loss: 0.7991 - val_acc: 0.0521
# Epoch 3/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0530 - acc: 0.1349 - val_loss: 0.7911 - val_acc: 0.0533
# Epoch 4/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0548 - acc: 0.1355 - val_loss: 0.7957 - val_acc: 0.0546
# Epoch 5/25
# ...
# Epoch 1/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0177 - acc: 0.1410 - val_loss: 0.8248 - val_acc: 0.0552
# Epoch 2/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0181 - acc: 0.1414 - val_loss: 0.8187 - val_acc: 0.0547
# Epoch 3/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0189 - acc: 0.1412 - val_loss: 0.8347 - val_acc: 0.0531
# Epoch 4/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0164 - acc: 0.1414 - val_loss: 0.8181 - val_acc: 0.0543
# Epoch 5/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0173 - acc: 0.1409 - val_loss: 0.8321 - val_acc: 0.0548
# Epoch 6/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0164 - acc: 0.1413 - val_loss: 0.8312 - val_acc: 0.0519
# Epoch 7/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0170 - acc: 0.1412 - val_loss: 0.8246 - val_acc: 0.0551
# Epoch 8/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0153 - acc: 0.1422 - val_loss: 0.8278 - val_acc: 0.0540
# Epoch 9/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0162 - acc: 0.1418 - val_loss: 0.8343 - val_acc: 0.0540
# Epoch 10/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0149 - acc: 0.1422 - val_loss: 0.8283 - val_acc: 0.0527
# Epoch 11/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0138 - acc: 0.1442 - val_loss: 0.8378 - val_acc: 0.0555
# Epoch 12/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0146 - acc: 0.1431 - val_loss: 0.8407 - val_acc: 0.0537
# Epoch 13/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0139 - acc: 0.1420 - val_loss: 0.8360 - val_acc: 0.0541
# Epoch 14/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0140 - acc: 0.1418 - val_loss: 0.8258 - val_acc: 0.0555
# Epoch 15/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0135 - acc: 0.1414 - val_loss: 0.8384 - val_acc: 0.0534
# Epoch 16/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0136 - acc: 0.1416 - val_loss: 0.8309 - val_acc: 0.0558
# Epoch 17/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0114 - acc: 0.1425 - val_loss: 0.8262 - val_acc: 0.0562
# Epoch 18/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0121 - acc: 0.1419 - val_loss: 0.8350 - val_acc: 0.0558
# Epoch 19/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0127 - acc: 0.1418 - val_loss: 0.8190 - val_acc: 0.0547
# Epoch 20/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0126 - acc: 0.1420 - val_loss: 0.8325 - val_acc: 0.0542
# Epoch 21/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0114 - acc: 0.1421 - val_loss: 0.8332 - val_acc: 0.0555
# Epoch 22/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0103 - acc: 0.1431 - val_loss: 0.8357 - val_acc: 0.0540
# Epoch 23/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0122 - acc: 0.1428 - val_loss: 0.8349 - val_acc: 0.0535
# Epoch 24/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0108 - acc: 0.1421 - val_loss: 0.8385 - val_acc: 0.0527
# Epoch 25/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0096 - acc: 0.1428 - val_loss: 0.8356 - val_acc: 0.0537
# --------------------------------------------------
# --------------------------------------------------
# academic credentials:
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
# tools/technologies web-cruiser , havij, tortoisesvn, jmeter, jenkins
#
# abhishek appanna kalagoudra
# 7#b/4, nav annapurna arti bldg, annapurna nagar, mobile: 9820385126
# adharwadi, kalyan(w).maharashtra-421301. email:abhishek.kalagoudra@gmail.com
# objective:
# want to work and implement my knowledge in an it organization to accomplish
# organizational goals and upgrade my knowledge.
# summary:
#  more than 3 years 7 months of software development experience.
#  got chance to join a start-up and be the first employee of the company to work with
# close connection to the highly experienced players in it industry.
#  have knowledge in objective c , c#, asp.net, xml, c++.
#  master of computer application from pune university.
#  strong analytical skills and experience in developing optimized, high performance
# systems.
#  experience in developing applications for iphone and ipad devices.
#  trained a fresher for iphone development.
#  knowledge in developing web based application and sites.
# experience:
#  aurality
# designation : software enginner
# platform : objective c (iphone), asp.net c# razor
# duration : june 2011 to till date
# description : aurality is a product based seed funded startup, where i got a
# lead role to handle the client side application development(iphone) with close connection
# to highly experienced players in the it industry. aurality is like a radio which reads out
# the content like blog and news feeds for you. now aurality has pivoted from its iphone
# application to a gifting site called giftery. before starting with giftery i was into product
# research and later the idea of giftery was brought into picture.
#  powerweave
# designation : software developer
#
# ---OUTPUT-----
# executive summarywant to work and implement my knowledge in an it organization to accomplishorganizational goals and upgrade my knowledge.summary:profile summary: got chance to join a start-up and be the first employee of the company to work withclose connection to the highly experienced players in it industry. have knowledge in objective c , c#, asp.net, xml, c++. strongly believe in long-term relations and teamwork. strong analytical and experience in an optimized, high technology experience in developing applications for iphone and ipad devices. trained a fresher for iphone development. knowledge in developing web based application and sites.
#                                                   --------------------------------------------------
# Iteration: 11
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0092 - acc: 0.1425 - val_loss: 0.8563 - val_acc: 0.0533
# Epoch 2/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0108 - acc: 0.1422 - val_loss: 0.8401 - val_acc: 0.0545
# Epoch 3/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0093 - acc: 0.1423 - val_loss: 0.8372 - val_acc: 0.0549
# Epoch 4/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0099 - acc: 0.1420 - val_loss: 0.8317 - val_acc: 0.0543
# Epoch 5/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0095 - acc: 0.1421 - val_loss: 0.8409 - val_acc: 0.0545
# Epoch 6/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0100 - acc: 0.1426 - val_loss: 0.8521 - val_acc: 0.0538
# Epoch 7/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0081 - acc: 0.1426 - val_loss: 0.8519 - val_acc: 0.0539
# Epoch 8/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0087 - acc: 0.1425 - val_loss: 0.8535 - val_acc: 0.0525
# Epoch 9/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0095 - acc: 0.1419 - val_loss: 0.8492 - val_acc: 0.0548
# Epoch 10/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0076 - acc: 0.1423 - val_loss: 0.8479 - val_acc: 0.0538
# Epoch 11/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0079 - acc: 0.1425 - val_loss: 0.8578 - val_acc: 0.0538
# Epoch 12/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0083 - acc: 0.1425 - val_loss: 0.8481 - val_acc: 0.0535
# Epoch 13/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0094 - acc: 0.1421 - val_loss: 0.8452 - val_acc: 0.0549
# Epoch 14/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0061 - acc: 0.1428 - val_loss: 0.8537 - val_acc: 0.0551
# Epoch 15/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0073 - acc: 0.1426 - val_loss: 0.8497 - val_acc: 0.0551
# Epoch 16/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0083 - acc: 0.1423 - val_loss: 0.8496 - val_acc: 0.0547
# Epoch 17/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0067 - acc: 0.1427 - val_loss: 0.8513 - val_acc: 0.0551
# Epoch 18/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0059 - acc: 0.1427 - val_loss: 0.8423 - val_acc: 0.0553
# Epoch 19/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0072 - acc: 0.1423 - val_loss: 0.8486 - val_acc: 0.0555
# Epoch 20/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0055 - acc: 0.1427 - val_loss: 0.8578 - val_acc: 0.0540
# Epoch 21/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0075 - acc: 0.1425 - val_loss: 0.8474 - val_acc: 0.0551
# Epoch 22/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0066 - acc: 0.1428 - val_loss: 0.8460 - val_acc: 0.0555
# Epoch 23/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0073 - acc: 0.1420 - val_loss: 0.8441 - val_acc: 0.0549
# Epoch 24/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0060 - acc: 0.1427 - val_loss: 0.8519 - val_acc: 0.0555
# Epoch 25/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0062 - acc: 0.1427 - val_loss: 0.8490 - val_acc: 0.0539
# --------------------------------------------------
# --------------------------------------------------
# experience summary:
#  3.5 + year of total experience in software testing and quality assurance.
#  clear understanding of software development life cycle models (sdlc) and software testing
# life cycle (stlc).
#  involved in understanding and analysis of requirement (srs) document.
#  involved in the writing and execution of the test cases using test-link, ms -excel based on
# business requirement and technical specifications and logging the defect in the bugzilla,
# jira.
#  experience of testing web based application.
#  experience of automating ui using robot framework with selenium library
#  experience of testing web application and database with algolia search engine
#  experience of testing api using rest client
#  experience of automating api using robot framework
#  thorough knowledge of software testing methodologies including functional, retesting,
# regression, browser compatibility, integration, and gui and negative testing of an
# application.
#  knowledge about software quality assurance, and agile methodology.
#  expertise in resolving bugs and issues with developers.
#  knowledge of using tortoisesvn & git
#  involved in deployment of test builds & automating it using jenkins.
#  involved in writing of sql queries.
#  good knowledge of unix.
#  good interpersonal skills & learn new technologies and undertake challenges.
# academic credentials:
#  b.e (information technology) with first class from pune university.
#  diploma in compute technology with first class under m.s.b.t.e..
#  ssc with first class from pune board
# technical experience summary:
# technology tools
# functional areas manual and automation testing
# software engineering selenium ide(1.0.7),bugzilla, jira, test-link, hp qc,
# tools/technologies web-cruiser , havij, tortoisesvn, jmeter, jenkins
#
# abhishek appanna kalagoudra
# 7#b/4, nav annapurna arti bldg, annapurna nagar, mobile: 9820385126
# adharwadi, kalyan(w).maharashtra-421301. email:abhishek.kalagoudra@gmail.com
# objective:
# want to work and implement my knowledge in an it organization to accomplish
# organizational goals and upgrade my knowledge.
# summary:
#
# ---OUTPUT-----
# experience summary: 3.5 + year of total experience in software testing and quality assurance. clear understanding of software development life cycle models (sdlc) and software testinglife cycle (stlc). involved in understanding and analysis of requirement (srs) document. involved in the writing and execution of the test cases using test-link, ms -excel based onbusiness requirement and technical specifications and logging the defect in the bugzilla,jira. experience of testing web based application. experience of automating ui using robot framework with selenium library experience of testing web application and database with algolia search engine experience of testing api using rest client experience of automating api using robot framework thorough knowledge of software testing methodologies including functional, retesting,regression, browser compatibility, integration, and gui and negative testing of an knowledge about software quality assurance, and agile methodology. expertise in resolving bugs and issues with developers. knowledge of using tortoisesvn & git involved in deployment of test builds & automating it using jenkins. involved in writing of sql queries. good knowledge of unix. good interpersonal skills & learn new technologies and undertake challenges.objective:want to work and implement my knowledge in an it organization to accomplishorganizational goals and upgrade my knowledge.summary:
#                                                   --------------------------------------------------
# Iteration: 12
# Train on 1634 samples, validate on 409 samples
# Epoch 1/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0060 - acc: 0.1430 - val_loss: 0.8565 - val_acc: 0.0555
# Epoch 2/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0048 - acc: 0.1431 - val_loss: 0.8422 - val_acc: 0.0545
# Epoch 3/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0057 - acc: 0.1427 - val_loss: 0.8555 - val_acc: 0.0550
# Epoch 4/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0055 - acc: 0.1426 - val_loss: 0.8528 - val_acc: 0.0547
# Epoch 5/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0052 - acc: 0.1430 - val_loss: 0.8622 - val_acc: 0.0552
# Epoch 6/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0052 - acc: 0.1428 - val_loss: 0.8599 - val_acc: 0.0556
# Epoch 7/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0040 - acc: 0.1433 - val_loss: 0.8555 - val_acc: 0.0550
# Epoch 8/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0056 - acc: 0.1425 - val_loss: 0.8570 - val_acc: 0.0547
# Epoch 9/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0058 - acc: 0.1425 - val_loss: 0.8560 - val_acc: 0.0553
# Epoch 10/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0062 - acc: 0.1425 - val_loss: 0.8668 - val_acc: 0.0553
# Epoch 11/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0046 - acc: 0.1426 - val_loss: 0.8559 - val_acc: 0.0553
# Epoch 12/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0049 - acc: 0.1426 - val_loss: 0.8566 - val_acc: 0.0543
# Epoch 13/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0045 - acc: 0.1427 - val_loss: 0.8467 - val_acc: 0.0526
# Epoch 14/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0055 - acc: 0.1424 - val_loss: 0.8569 - val_acc: 0.0547
# Epoch 15/25
# 1634/1634 [==============================] - 40s 24ms/step - loss: 0.0030 - acc: 0.1429 - val_loss: 0.8606 - val_acc: 0.0547
# Epoch 16/25
# 1634/1634 [==============================] - 40s 25ms/step - loss: 0.0061 - acc: 0.1424 - val_loss: 0.8573 - val_acc: 0.0536
# Epoch 17/25
#  450/1634 [=======>......................] - ETA: 28s - loss: 0.0063 - acc: 0.1348
