# %% [markdown]
# # Sequence to Sequence model to extract summary,objective from resume (input: resume line by line)

# %% [markdown]
# ## 207 resumes

# %%
from __future__ import print_function
import csv,os
import collections
from keras.models import Model,load_model
from keras.layers import Input,LSTM,Dense
from keras.callbacks import ModelCheckpoint
import numpy as np

batch_size=90
epochs=25
latent_dim=128
data_path="/home/santhosh/resumes_folder/custom_annotator/annotator-server/static/files/Data_Tracter_Resumes_in_TXT/csv"

# %% [markdown]
# ## vectorizing the data

# %%
input_resumes=[]
output_summary=[]
input_tokens=collections.Counter()
output_tokens=set()
files=os.listdir(data_path)
count=0
line=0;
for file in files[:25]:
    with open(data_path+'/'+file,'r') as csv_file:
        reader=csv.reader(csv_file)
        count=0
        for Input_text,output in reader:
            Input_text=Input_text.strip().lower()
            Input_text=Input_text+' \n'
            if(output=='1'):
                output_text=Input_text+' \n'
            else:
                output_text=""
            
            # We use "<SOL>" as the "start sequence" character
            # for the targets, and "<EOL>" as "end sequence" character.
            output_text='<SOL> '+output_text+' <EOL>'
            input_resumes.append(Input_text)
            output_summary.append(output_text)
            for word in Input_text.split():
                if word not in input_tokens:
                    input_tokens[word]+=1
            for word in output_text.split():
                if word not in output_tokens:
                    output_tokens.add(word)
            if count==40:
                break
            count+=1

# %%
print(len(input_tokens))
num_encoder_tokens=min(len(input_tokens),1000)
input_tokens=[word for word,count in input_tokens.most_common(num_encoder_tokens-1)]
input_tokens=sorted(list(input_tokens))
output_tokens=sorted(list(output_tokens))
num_decoder_tokens=len(output_tokens)
max_encoder_seq_len=max([len(text.split()) for text in input_resumes])
max_decoder_seq_len=max([len(text.split()) for text in output_summary])

print('Number of samples:',len(input_resumes))
print('number of unique input token:',num_encoder_tokens)
print('number of unique output token:',num_decoder_tokens)
print('Max Sequence length for inputs:',max_encoder_seq_len)
print('Max Sequence length for outputs:',max_decoder_seq_len)
# Out:
# 2611
# Number of samples: 1018
# number of unique input token: 1000
# number of unique output token: 1215
# Max Sequence length for inputs: 24
# Max Sequence length for outputs: 24

# %% [markdown]
# ## defining token2index

# %%
input_token2index=dict([(word,i) for i,word in enumerate(input_tokens)])
output_token2index=dict([(word,i) for i,word in enumerate(output_tokens)])
input_token2index['UNK']=num_encoder_tokens-1

# %% [markdown]
# ## defing encoder_input,decoder_input and decoder_output

# %%
encoder_input_data=np.zeros((len(input_resumes),max_encoder_seq_len,num_encoder_tokens),dtype='float32')
decoder_input_data=np.zeros((len(input_resumes),max_decoder_seq_len,num_decoder_tokens),dtype='float32')
decoder_target_data=np.zeros((len(input_resumes),max_decoder_seq_len,num_decoder_tokens),dtype='float32')

# %% [markdown]
# ## creating training dataset

# %%
for i,(input_text,target_text) in enumerate(zip(input_resumes,output_summary)):
    for t,word in enumerate(input_text.split()[:max_encoder_seq_len]):
        if word not in input_token2index:
            word="UNK"
        encoder_input_data[i,t,input_token2index[word]]=1
        
    for t,word in enumerate(target_text.split()):
        decoder_input_data[i,t,output_token2index[word]]=1
        # decoder_target_data is ahead of decoder_input_data by one timestep
        if t>0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i,t-1,output_token2index[word]]=1

# %% [markdown]
# ## Define an input sequence and process it.

# %%
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %% [markdown]
# ## Set up the decoder, using encoder_states as initial state.

# %%
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %% [markdown]
# ## Define the model that will turn
# ## `encoder_input_data` & `decoder_input_data` into `decoder_target_data`

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=["accuracy"])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_33 (InputLayer)           (None, None, 1000)   0
# __________________________________________________________________________________________________
# input_34 (InputLayer)           (None, None, 1215)   0
# __________________________________________________________________________________________________
# lstm_17 (LSTM)                  [(None, 128), (None, 578048      input_33[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  [(None, None, 128),  688128      input_34[0][0]
#                                                                  lstm_17[0][1]
#                                                                  lstm_17[0][2]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, None, 1215)   156735      lstm_18[0][0]
# ==================================================================================================
# Total params: 1,422,911
# Trainable params: 1,422,911
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## function to test model

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_word_index = dict(
    (i, word) for word, i in input_token2index.items())
reverse_target_word_index = dict(
    (i, word) for word, i in output_token2index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, output_token2index['<SOL>']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = reverse_target_word_index[sampled_token_index]
        decoded_sentence += ' '+sampled_word

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_word == '<EOL>' or
           len(decoded_sentence.split()) > max_decoder_seq_len):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]
    if('<EOL>' in decoded_sentence):
        decoded_sentence=" ".join(decoded_sentence.split()[:-1])
    return decoded_sentence

# %% [markdown]
# ## Run training

# %%
iteration=0
"""
# load weights
print('loading the weights')
model=load_model('resume_level.h5')

# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate([encoder_input_data, decoder_input_data], decoder_target_data,verbose=0)
print("%s: %.2f%%\n\n" % (model.metrics_names[1], scores[1]*100))
print("Testing Samples\n"+"-"*50)
for i in range(1):
    index=np.random.randint(len(input_resumes))
    encoded_input_sequence=encoder_input_data[index: index + 1]
    output_sequence=decode_sequence(encoded_input_sequence)
    print("-"*50)
    print(input_resumes[index])
    print(" "*50)
    print("*"*50+"\nOUTPUT"+" "*50)
    print(output_sequence)
    print("-"*50+"\n"+" "*50)
"""
iteration_file="/home/santhosh/resumes_folder/keras/extract_summary_and_objective/iteration_resume_line_level.txt"
try:
    file=open(iteration_file,'r')
    last_line=file.read().split('\n')[-2]
    print('file_data,',last_line)
    iteration=int(last_line.split(':')[1])
    #print(iteration)
    file.close()
    
except:
    print('no file exist')

# checkpoint
filepath="resume_line_level_checkpoints.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

while True:
    print('Iteration:',iteration+1)
    #training
    model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,callbacks=callbacks_list)
    #prepare sample_data to test 5 samples:
    print("-"*50)
    index=int(np.random.randint(len(input_resumes)/40*0.8))
    test_input=""
    test_output=""
    for i in range(40):
        encoded_input_sequence=(encoder_input_data[index]).reshape((1,max_encoder_seq_len,num_encoder_tokens))
        #print(encoded_input_sequence.shape,max_encoder_seq_len,num_encoder_tokens,max_encoder_seq_len*num_encoder_tokens)
        #print(encoded_input_sequence)
        #.reshape((1,max_encoder_seq_len,num_encoder_tokens))
        output_sequence=decode_sequence(encoded_input_sequence)
        test_input+=input_resumes[index]
        test_output+=output_sequence
        index+=1
    print("-"*50)
    print(test_input)
    print("---OUTPUT-----")
    print(test_output)
    print(" "*50+"-"*50)
        
        
        
    # Save model
    file=open(iteration_file,'a')
    file.write('iteration:'+str(iteration+1)+'\n')
    file.close()
    iteration+=1
    model.save('resume_line_level.h5')
# Out:
# file_data, iteration:6
# Iteration: 7
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
# 814/814 [==============================] - 29s 36ms/step - loss: 1.2167 - acc: 0.0363 - val_loss: 0.5803 - val_acc: 0.0417
# /home/santhosh/anaconda3/envs/pydl/lib/python3.5/site-packages/keras/engine/network.py:888: UserWarning: Layer lstm_18 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_17/while/Exit_2:0' shape=(?, 128) dtype=float32>, <tf.Tensor 'lstm_17/while/Exit_3:0' shape=(?, 128) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# Epoch 2/25
# 814/814 [==============================] - 26s 31ms/step - loss: 0.9725 - acc: 0.0417 - val_loss: 0.5588 - val_acc: 0.0417
# Epoch 3/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9494 - acc: 0.0417 - val_loss: 0.5635 - val_acc: 0.0417
# Epoch 4/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9415 - acc: 0.0417 - val_loss: 0.5737 - val_acc: 0.0417
# Epoch 5/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9357 - acc: 0.0417 - val_loss: 0.5812 - val_acc: 0.0417
# Epoch 6/25
# 814/814 [==============================] - 28s 35ms/step - loss: 0.9317 - acc: 0.0417 - val_loss: 0.5844 - val_acc: 0.0417
# Epoch 7/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9274 - acc: 0.0417 - val_loss: 0.5955 - val_acc: 0.0417
# Epoch 8/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9236 - acc: 0.0417 - val_loss: 0.6113 - val_acc: 0.0421
# Epoch 9/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.9232 - acc: 0.0418 - val_loss: 0.6036 - val_acc: 0.0417
# Epoch 10/25
# 814/814 [==============================] - 26s 33ms/step - loss: 0.9144 - acc: 0.0417 - val_loss: 0.6076 - val_acc: 0.0417
# Epoch 11/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9107 - acc: 0.0417 - val_loss: 0.6162 - val_acc: 0.0417
# Epoch 12/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9057 - acc: 0.0422 - val_loss: 0.6156 - val_acc: 0.0421
# Epoch 13/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.9033 - acc: 0.0428 - val_loss: 0.6291 - val_acc: 0.0423
# Epoch 14/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8984 - acc: 0.0424 - val_loss: 0.6428 - val_acc: 0.0415
# Epoch 15/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8967 - acc: 0.0429 - val_loss: 0.6334 - val_acc: 0.0425
# Epoch 16/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8890 - acc: 0.0428 - val_loss: 0.6493 - val_acc: 0.0429
# Epoch 17/25
# 814/814 [==============================] - 25s 31ms/step - loss: 0.8874 - acc: 0.0430 - val_loss: 0.6466 - val_acc: 0.0425
# Epoch 18/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8824 - acc: 0.0432 - val_loss: 0.6473 - val_acc: 0.0421
# Epoch 19/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8808 - acc: 0.0432 - val_loss: 0.6546 - val_acc: 0.0419
# Epoch 20/25
# 814/814 [==============================] - 26s 31ms/step - loss: 0.8746 - acc: 0.0439 - val_loss: 0.6544 - val_acc: 0.0429
# Epoch 21/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8733 - acc: 0.0433 - val_loss: 0.6587 - val_acc: 0.0423
# Epoch 22/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8663 - acc: 0.0438 - val_loss: 0.6624 - val_acc: 0.0423
# Epoch 23/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8639 - acc: 0.0437 - val_loss: 0.6648 - val_acc: 0.0419
# Epoch 24/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8603 - acc: 0.0441 - val_loss: 0.6708 - val_acc: 0.0429
# Epoch 25/25
# 814/814 [==============================] - 29s 35ms/step - loss: 0.8546 - acc: 0.0441 - val_loss: 0.6821 - val_acc: 0.0417
# --------------------------------------------------
# --------------------------------------------------
# individuality is recognized by work, and to achieve professional satisfaction by meeting
# higher responsibilities and involving in competent work areas.
# profile summary
# • experienced in oops implementation with javascript and enyo for developing and delivering projects.
# • have good exposure and experience in web application framework development using html5, css3,
# and jquery.
# • experienced in developing projects using mvc techniques.
# • 6 months onsite experience for web application framework support.
# • 2 months onsite experience for reference application (file browser) development.
# • 6 months industrial training in advanced computing.
# • sound knowledge of porting web application in android phone and debugging using web inspector.
# • 3 months project experience in java (jsp & servlets) and oracle.
# • worked on technologies like less.js and node.js
# • efficient in debugging node application using node inspector.
# • experienced in creating web application using worker thread which increases performance.
# technical skill details
# programming
# languages
# c, c++ have relevant experience in programming and
# debugging applications on windows and linux
# platform
# java undergone 6 months training in jsp, servlets
# and core java
# scripting
# languages
# javascript have sound knowledge of javascript
# web designing html5, xml, css3,
# json
# expert with relevant experience in
# developing applications using these
# technologies
# ide sublime text ,visual
# cv
# aravind arivarasan
# career objective:
# to pursue a challenging and growth oriented career which would mould me into a complete
# professional by applying both my technical and interpersonal skills.
# professional summary:
# i am an associate software engineer at cordys(is now opentext) software india
# private limited having work experience of 1 year. software developer of applications
#
# ---OUTPUT-----
#
#                                                   --------------------------------------------------
# Iteration: 8
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8513 - acc: 0.0442 - val_loss: 0.6888 - val_acc: 0.0431
# Epoch 2/25
# 814/814 [==============================] - 27s 34ms/step - loss: 0.8479 - acc: 0.0438 - val_loss: 0.6875 - val_acc: 0.0419
# Epoch 3/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8434 - acc: 0.0450 - val_loss: 0.6757 - val_acc: 0.0427
# Epoch 4/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8417 - acc: 0.0444 - val_loss: 0.6862 - val_acc: 0.0419
# Epoch 5/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8375 - acc: 0.0450 - val_loss: 0.6887 - val_acc: 0.0417
# Epoch 6/25
# 814/814 [==============================] - 25s 31ms/step - loss: 0.8328 - acc: 0.0446 - val_loss: 0.6742 - val_acc: 0.0386
# Epoch 7/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8326 - acc: 0.0445 - val_loss: 0.6842 - val_acc: 0.0392
# Epoch 8/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8269 - acc: 0.0459 - val_loss: 0.6888 - val_acc: 0.0423
# Epoch 9/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.8221 - acc: 0.0451 - val_loss: 0.6842 - val_acc: 0.0423
# Epoch 10/25
# 814/814 [==============================] - 26s 31ms/step - loss: 0.8129 - acc: 0.0464 - val_loss: 0.7067 - val_acc: 0.0341
# Epoch 11/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8176 - acc: 0.0458 - val_loss: 0.6921 - val_acc: 0.0419
# Epoch 12/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8050 - acc: 0.0469 - val_loss: 0.6913 - val_acc: 0.0417
# Epoch 13/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8044 - acc: 0.0467 - val_loss: 0.7103 - val_acc: 0.0423
# Epoch 14/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.8061 - acc: 0.0461 - val_loss: 0.6926 - val_acc: 0.0417
# Epoch 15/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7985 - acc: 0.0467 - val_loss: 0.6922 - val_acc: 0.0429
# Epoch 16/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7948 - acc: 0.0472 - val_loss: 0.7075 - val_acc: 0.0404
# Epoch 17/25
# 814/814 [==============================] - 27s 34ms/step - loss: 0.7859 - acc: 0.0486 - val_loss: 0.7044 - val_acc: 0.0413
# Epoch 18/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7893 - acc: 0.0492 - val_loss: 0.6824 - val_acc: 0.0406
# Epoch 19/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7782 - acc: 0.0489 - val_loss: 0.6932 - val_acc: 0.0394
# Epoch 20/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7745 - acc: 0.0494 - val_loss: 0.6889 - val_acc: 0.0417
# Epoch 21/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7787 - acc: 0.0489 - val_loss: 0.6877 - val_acc: 0.0359
# Epoch 22/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7672 - acc: 0.0493 - val_loss: 0.6967 - val_acc: 0.0359
# Epoch 23/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7671 - acc: 0.0487 - val_loss: 0.6869 - val_acc: 0.0417
# Epoch 24/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7616 - acc: 0.0488 - val_loss: 0.6931 - val_acc: 0.0419
# Epoch 25/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7521 - acc: 0.0501 - val_loss: 0.7156 - val_acc: 0.0278
# --------------------------------------------------
# --------------------------------------------------
# anshu_resume_latest
# anshu agrawal phone no - 7829401605
# email id - anshu099.agrawal@gmail.com
# github id - anshu099
# it professional with over 2.6 years of work experience in web application framework
# development & currently working in lg soft india as a senior software engineer.
# objective:
# seeking a position to utilize my technical and leadership skills and abilities in the
# information technology industry, a job where growth prospects are unlimited and
# individuality is recognized by work, and to achieve professional satisfaction by meeting
# higher responsibilities and involving in competent work areas.
# profile summary
# • experienced in oops implementation with javascript and enyo for developing and delivering projects.
# • have good exposure and experience in web application framework development using html5, css3,
# and jquery.
# • experienced in developing projects using mvc techniques.
# • 6 months onsite experience for web application framework support.
# • 2 months onsite experience for reference application (file browser) development.
# • 6 months industrial training in advanced computing.
# • sound knowledge of porting web application in android phone and debugging using web inspector.
# • 3 months project experience in java (jsp & servlets) and oracle.
# • worked on technologies like less.js and node.js
# • efficient in debugging node application using node inspector.
# • experienced in creating web application using worker thread which increases performance.
# technical skill details
# programming
# languages
# c, c++ have relevant experience in programming and
# debugging applications on windows and linux
# platform
# java undergone 6 months training in jsp, servlets
# and core java
# scripting
# languages
# javascript have sound knowledge of javascript
# web designing html5, xml, css3,
# json
# expert with relevant experience in
# developing applications using these
# technologies
#
# ---OUTPUT-----
#  knowledge in in to and and and and and and and knowledge in to to and and and and and and and in in to and and and and and and and and in to to and and and and and and and and and experienced in in to and and and and and and and experienced in in in and and and and and in to to and and and and and and and and knowledge in in to and and and and and and knowledge in to to and and and and and and and knowledge in to to and and and and and and and  in in to and and and and and and and in to to and and and and and and and and and in to to and and and and and and and and experienced in in to and and and and and and in in to and and and and and and and and experienced in in in and and and and and and experienced in in to and and and and and and experienced in in in and and and and and and experienced in in in and and and and and and experienced in in in and and and and and and
#                                                   --------------------------------------------------
# Iteration: 9
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7614 - acc: 0.0487 - val_loss: 0.7291 - val_acc: 0.0286
# Epoch 2/25
# 814/814 [==============================] - 28s 34ms/step - loss: 0.7528 - acc: 0.0497 - val_loss: 0.6914 - val_acc: 0.0400
# Epoch 3/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.7392 - acc: 0.0515 - val_loss: 0.6882 - val_acc: 0.0368
# Epoch 4/25
# 814/814 [==============================] - 32s 39ms/step - loss: 0.7389 - acc: 0.0507 - val_loss: 0.6866 - val_acc: 0.0419
# Epoch 5/25
# 814/814 [==============================] - 35s 43ms/step - loss: 0.7428 - acc: 0.0505 - val_loss: 0.7158 - val_acc: 0.0386
# Epoch 6/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7260 - acc: 0.0517 - val_loss: 0.7045 - val_acc: 0.0421
# Epoch 7/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7313 - acc: 0.0504 - val_loss: 0.6793 - val_acc: 0.0417
# Epoch 8/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.7230 - acc: 0.0522 - val_loss: 0.6833 - val_acc: 0.0417
# Epoch 9/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7185 - acc: 0.0531 - val_loss: 0.7006 - val_acc: 0.0380
# Epoch 10/25
# 814/814 [==============================] - 26s 31ms/step - loss: 0.7205 - acc: 0.0525 - val_loss: 0.7012 - val_acc: 0.0423
# Epoch 11/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7118 - acc: 0.0523 - val_loss: 0.6867 - val_acc: 0.0406
# Epoch 12/25
# 814/814 [==============================] - 26s 32ms/step - loss: 0.7035 - acc: 0.0533 - val_loss: 0.6750 - val_acc: 0.0408
# Epoch 13/25
# 814/814 [==============================] - 29s 36ms/step - loss: 0.7038 - acc: 0.0527 - val_loss: 0.6864 - val_acc: 0.0376
# Epoch 14/25
# 814/814 [==============================] - 33s 40ms/step - loss: 0.6914 - acc: 0.0528 - val_loss: 0.7041 - val_acc: 0.0417
# Epoch 15/25
# 814/814 [==============================] - 31s 37ms/step - loss: 0.6962 - acc: 0.0525 - val_loss: 0.7019 - val_acc: 0.0402
# Epoch 16/25
# 814/814 [==============================] - 36s 45ms/step - loss: 0.6856 - acc: 0.0538 - val_loss: 0.6871 - val_acc: 0.0419
# Epoch 17/25
# 814/814 [==============================] - 28s 34ms/step - loss: 0.6843 - acc: 0.0534 - val_loss: 0.6968 - val_acc: 0.0429
# Epoch 18/25
# 814/814 [==============================] - 25s 31ms/step - loss: 0.6756 - acc: 0.0544 - val_loss: 0.6907 - val_acc: 0.0425
# Epoch 19/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.6661 - acc: 0.0553 - val_loss: 0.7038 - val_acc: 0.0419
# Epoch 20/25
# 814/814 [==============================] - 31s 38ms/step - loss: 0.6711 - acc: 0.0552 - val_loss: 0.6941 - val_acc: 0.0431
# Epoch 21/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.6611 - acc: 0.0561 - val_loss: 0.6829 - val_acc: 0.0417
# Epoch 22/25
# 814/814 [==============================] - 35s 42ms/step - loss: 0.6598 - acc: 0.0557 - val_loss: 0.6919 - val_acc: 0.0419
# Epoch 23/25
# 814/814 [==============================] - 29s 35ms/step - loss: 0.6498 - acc: 0.0566 - val_loss: 0.6772 - val_acc: 0.0421
# Epoch 24/25
# 814/814 [==============================] - 27s 33ms/step - loss: 0.6464 - acc: 0.0562 - val_loss: 0.7083 - val_acc: 0.0419
# Epoch 25/25
# 814/814 [==============================] - 39s 47ms/step - loss: 0.6406 - acc: 0.0575 - val_loss: 0.6948 - val_acc: 0.0425
# --------------------------------------------------
# --------------------------------------------------
# • have good exposure and experience in web application framework development using html5, css3,
# and jquery.
# • experienced in developing projects using mvc techniques.
# • 6 months onsite experience for web application framework support.
# • 2 months onsite experience for reference application (file browser) development.
# • 6 months industrial training in advanced computing.
# • sound knowledge of porting web application in android phone and debugging using web inspector.
# • 3 months project experience in java (jsp & servlets) and oracle.
# • worked on technologies like less.js and node.js
# • efficient in debugging node application using node inspector.
# • experienced in creating web application using worker thread which increases performance.
# technical skill details
# programming
# languages
# c, c++ have relevant experience in programming and
# debugging applications on windows and linux
# platform
# java undergone 6 months training in jsp, servlets
# and core java
# scripting
# languages
# javascript have sound knowledge of javascript
# web designing html5, xml, css3,
# json
# expert with relevant experience in
# developing applications using these
# technologies
# ide sublime text ,visual
# cv
# aravind arivarasan
# career objective:
# to pursue a challenging and growth oriented career which would mould me into a complete
# professional by applying both my technical and interpersonal skills.
# professional summary:
# i am an associate software engineer at cordys(is now opentext) software india
# private limited having work experience of 1 year. software developer of applications
# using cordys bop 4.3, html5, css3, javascript, jquery, oojs, ajax, web services,
# mysql.
# education
# degree specialization university /
#
# ---OUTPUT-----
#  good knowledge in of of experience in good in of of experience in good in of of experience in in good in of of experience in good knowledge in of of experience in good in of of experience in good in of of experience in good in of of experience in to to and and and knowledge in of development and and
#                                                   --------------------------------------------------
# Iteration: 10
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.6392 - acc: 0.0571 - val_loss: 0.7053 - val_acc: 0.0345
# Epoch 2/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.6344 - acc: 0.0583 - val_loss: 0.6941 - val_acc: 0.0425
# Epoch 3/25
# 814/814 [==============================] - 33s 41ms/step - loss: 0.6250 - acc: 0.0587 - val_loss: 0.6953 - val_acc: 0.0423
# Epoch 4/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.6281 - acc: 0.0574 - val_loss: 0.6926 - val_acc: 0.0413
# Epoch 5/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.6156 - acc: 0.0579 - val_loss: 0.6993 - val_acc: 0.0419
# Epoch 6/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.6096 - acc: 0.0595 - val_loss: 0.7055 - val_acc: 0.0423
# Epoch 7/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.6124 - acc: 0.0601 - val_loss: 0.7007 - val_acc: 0.0417
# Epoch 8/25
# 814/814 [==============================] - 41s 51ms/step - loss: 0.6061 - acc: 0.0596 - val_loss: 0.6818 - val_acc: 0.0404
# Epoch 9/25
# 814/814 [==============================] - 40s 49ms/step - loss: 0.5920 - acc: 0.0610 - val_loss: 0.7010 - val_acc: 0.0421
# Epoch 10/25
# 814/814 [==============================] - 46s 56ms/step - loss: 0.5935 - acc: 0.0600 - val_loss: 0.6942 - val_acc: 0.0429
# Epoch 11/25
# 814/814 [==============================] - 40s 49ms/step - loss: 0.5873 - acc: 0.0612 - val_loss: 0.7331 - val_acc: 0.0278
# Epoch 12/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.5879 - acc: 0.0606 - val_loss: 0.7042 - val_acc: 0.0417
# Epoch 13/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.5734 - acc: 0.0626 - val_loss: 0.6935 - val_acc: 0.0394
# Epoch 14/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.5776 - acc: 0.0624 - val_loss: 0.7053 - val_acc: 0.0386
# Epoch 15/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.5668 - acc: 0.0627 - val_loss: 0.7014 - val_acc: 0.0429
# Epoch 16/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.5683 - acc: 0.0626 - val_loss: 0.6958 - val_acc: 0.0425
# Epoch 17/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.5562 - acc: 0.0638 - val_loss: 0.6830 - val_acc: 0.0423
# Epoch 18/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.5584 - acc: 0.0632 - val_loss: 0.6941 - val_acc: 0.0427
# Epoch 19/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.5435 - acc: 0.0650 - val_loss: 0.7107 - val_acc: 0.0413
# Epoch 20/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.5425 - acc: 0.0660 - val_loss: 0.7082 - val_acc: 0.0421
# Epoch 21/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.5407 - acc: 0.0652 - val_loss: 0.6901 - val_acc: 0.0427
# Epoch 22/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.5381 - acc: 0.0664 - val_loss: 0.6987 - val_acc: 0.0427
# Epoch 23/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.5267 - acc: 0.0673 - val_loss: 0.7039 - val_acc: 0.0408
# Epoch 24/25
# 814/814 [==============================] - 40s 49ms/step - loss: 0.5325 - acc: 0.0674 - val_loss: 0.7004 - val_acc: 0.0431
# Epoch 25/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.5115 - acc: 0.0704 - val_loss: 0.7332 - val_acc: 0.0313
# --------------------------------------------------
# --------------------------------------------------
# • experienced in oops implementation with javascript and enyo for developing and delivering projects.
# • have good exposure and experience in web application framework development using html5, css3,
# and jquery.
# • experienced in developing projects using mvc techniques.
# • 6 months onsite experience for web application framework support.
# • 2 months onsite experience for reference application (file browser) development.
# • 6 months industrial training in advanced computing.
# • sound knowledge of porting web application in android phone and debugging using web inspector.
# • 3 months project experience in java (jsp & servlets) and oracle.
# • worked on technologies like less.js and node.js
# • efficient in debugging node application using node inspector.
# • experienced in creating web application using worker thread which increases performance.
# technical skill details
# programming
# languages
# c, c++ have relevant experience in programming and
# debugging applications on windows and linux
# platform
# java undergone 6 months training in jsp, servlets
# and core java
# scripting
# languages
# javascript have sound knowledge of javascript
# web designing html5, xml, css3,
# json
# expert with relevant experience in
# developing applications using these
# technologies
# ide sublime text ,visual
# cv
# aravind arivarasan
# career objective:
# to pursue a challenging and growth oriented career which would mould me into a complete
# professional by applying both my technical and interpersonal skills.
# professional summary:
# i am an associate software engineer at cordys(is now opentext) software india
# private limited having work experience of 1 year. software developer of applications
# using cordys bop 4.3, html5, css3, javascript, jquery, oojs, ajax, web services,
# mysql.
# education
#
# ---OUTPUT-----
#  good working of experience in experience in development software development and good knowledge of experience in web application application experience in of development using application and using  good in of the the of of the the the for for the the the the the the the the the the the the experience in of development in application and and using experience in of development using application and using good knowledge of experience in web application and experience in of development in development and and using experience in of development application and robot and good in of the experience in the and and with experience in of development using application and using good in of experience in web application and experience in experience in web application and and (n.i.t.) and to to have knowledge in experience in web application experienced in experience in web application application good in of experience in web application good in of experience in web applicationand to to to work a a part of a a and provides provides to to to good in of experience in application and experienced in experience in web application work to to to and and and with with to to good knowledge in of web application in application and good knowledge in experience in web application
#                                                   --------------------------------------------------
# Iteration: 11
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.5128 - acc: 0.0695 - val_loss: 0.7294 - val_acc: 0.0353
# Epoch 2/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.5137 - acc: 0.0688 - val_loss: 0.6987 - val_acc: 0.0437
# Epoch 3/25
# 814/814 [==============================] - 41s 50ms/step - loss: 0.5050 - acc: 0.0704 - val_loss: 0.7062 - val_acc: 0.0406
# Epoch 4/25
# 814/814 [==============================] - 45s 56ms/step - loss: 0.4959 - acc: 0.0726 - val_loss: 0.7178 - val_acc: 0.0421
# Epoch 5/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.4916 - acc: 0.0734 - val_loss: 0.7067 - val_acc: 0.0427
# Epoch 6/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.4868 - acc: 0.0732 - val_loss: 0.7136 - val_acc: 0.0404
# Epoch 7/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.4945 - acc: 0.0727 - val_loss: 0.7081 - val_acc: 0.0413
# Epoch 8/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.4752 - acc: 0.0768 - val_loss: 0.7026 - val_acc: 0.0419
# Epoch 9/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.4758 - acc: 0.0763 - val_loss: 0.7077 - val_acc: 0.0415
# Epoch 10/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.4695 - acc: 0.0779 - val_loss: 0.7032 - val_acc: 0.0400
# Epoch 11/25
# 814/814 [==============================] - 40s 50ms/step - loss: 0.4632 - acc: 0.0788 - val_loss: 0.7083 - val_acc: 0.0431
# Epoch 12/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.4546 - acc: 0.0806 - val_loss: 0.7157 - val_acc: 0.0384
# Epoch 13/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.4584 - acc: 0.0807 - val_loss: 0.7166 - val_acc: 0.0423
# Epoch 14/25
# 814/814 [==============================] - 41s 50ms/step - loss: 0.4509 - acc: 0.0817 - val_loss: 0.7038 - val_acc: 0.0419
# Epoch 15/25
# 814/814 [==============================] - 43s 53ms/step - loss: 0.4465 - acc: 0.0819 - val_loss: 0.7220 - val_acc: 0.0429
# Epoch 16/25
# 814/814 [==============================] - 43s 53ms/step - loss: 0.4395 - acc: 0.0838 - val_loss: 0.7149 - val_acc: 0.0423
# Epoch 17/25
# 814/814 [==============================] - 42s 51ms/step - loss: 0.4351 - acc: 0.0854 - val_loss: 0.7119 - val_acc: 0.0425
# Epoch 18/25
# 814/814 [==============================] - 48s 59ms/step - loss: 0.4304 - acc: 0.0867 - val_loss: 0.7071 - val_acc: 0.0423
# Epoch 19/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.4236 - acc: 0.0874 - val_loss: 0.7189 - val_acc: 0.0429
# Epoch 20/25
# 814/814 [==============================] - 40s 49ms/step - loss: 0.4221 - acc: 0.0880 - val_loss: 0.7188 - val_acc: 0.0419
# Epoch 21/25
# 814/814 [==============================] - 43s 53ms/step - loss: 0.4168 - acc: 0.0899 - val_loss: 0.7263 - val_acc: 0.0417
# Epoch 22/25
# 814/814 [==============================] - 40s 50ms/step - loss: 0.4141 - acc: 0.0903 - val_loss: 0.7117 - val_acc: 0.0406
# Epoch 23/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.4058 - acc: 0.0942 - val_loss: 0.7188 - val_acc: 0.0433
# Epoch 24/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.3934 - acc: 0.0969 - val_loss: 0.7243 - val_acc: 0.0398
# Epoch 25/25
# 814/814 [==============================] - 40s 50ms/step - loss: 0.3980 - acc: 0.0930 - val_loss: 0.7088 - val_acc: 0.0408
# --------------------------------------------------
# --------------------------------------------------
# • sound knowledge of porting web application in android phone and debugging using web inspector.
# • 3 months project experience in java (jsp & servlets) and oracle.
# • worked on technologies like less.js and node.js
# • efficient in debugging node application using node inspector.
# • experienced in creating web application using worker thread which increases performance.
# technical skill details
# programming
# languages
# c, c++ have relevant experience in programming and
# debugging applications on windows and linux
# platform
# java undergone 6 months training in jsp, servlets
# and core java
# scripting
# languages
# javascript have sound knowledge of javascript
# web designing html5, xml, css3,
# json
# expert with relevant experience in
# developing applications using these
# technologies
# ide sublime text ,visual
# cv
# aravind arivarasan
# career objective:
# to pursue a challenging and growth oriented career which would mould me into a complete
# professional by applying both my technical and interpersonal skills.
# professional summary:
# i am an associate software engineer at cordys(is now opentext) software india
# private limited having work experience of 1 year. software developer of applications
# using cordys bop 4.3, html5, css3, javascript, jquery, oojs, ajax, web services,
# mysql.
# education
# degree specialization university /
# institution
# city country cgpa year of
# passing
# bachelor of
# technology
# computer
#
# ---OUTPUT-----
#  involved in the years of of of of software development development experience in software development and and functional, system, regression, acceptance experience in software development and and functional, and knowledge in developing web and using and knowledge in developing web and and san).and to work to work my my and leadership and would would into into into into a my work and to to team and with fast and an having knowledge in of web years of experience in android using using
#                                                   --------------------------------------------------
# Iteration: 12
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
# 814/814 [==============================] - 41s 50ms/step - loss: 0.3909 - acc: 0.0982 - val_loss: 0.7328 - val_acc: 0.0396
# Epoch 2/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.3879 - acc: 0.0989 - val_loss: 0.7175 - val_acc: 0.0425
# Epoch 3/25
# 814/814 [==============================] - 41s 50ms/step - loss: 0.3779 - acc: 0.1005 - val_loss: 0.7318 - val_acc: 0.0378
# Epoch 4/25
# 814/814 [==============================] - 40s 49ms/step - loss: 0.3798 - acc: 0.1029 - val_loss: 0.7525 - val_acc: 0.0270
# Epoch 5/25
# 814/814 [==============================] - 41s 51ms/step - loss: 0.3737 - acc: 0.1022 - val_loss: 0.7209 - val_acc: 0.0423
# Epoch 6/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.3688 - acc: 0.1045 - val_loss: 0.7269 - val_acc: 0.0406
# Epoch 7/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.3650 - acc: 0.1059 - val_loss: 0.7190 - val_acc: 0.0435
# Epoch 8/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.3538 - acc: 0.1086 - val_loss: 0.7225 - val_acc: 0.0421
# Epoch 9/25
# 814/814 [==============================] - 37s 45ms/step - loss: 0.3560 - acc: 0.1094 - val_loss: 0.7358 - val_acc: 0.0415
# Epoch 10/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.3470 - acc: 0.1107 - val_loss: 0.7303 - val_acc: 0.0427
# Epoch 11/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.3450 - acc: 0.1119 - val_loss: 0.7459 - val_acc: 0.0417
# Epoch 12/25
# 814/814 [==============================] - 45s 55ms/step - loss: 0.3456 - acc: 0.1139 - val_loss: 0.7250 - val_acc: 0.0413
# Epoch 13/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.3289 - acc: 0.1187 - val_loss: 0.7344 - val_acc: 0.0419
# Epoch 14/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.3333 - acc: 0.1147 - val_loss: 0.7771 - val_acc: 0.0345
# Epoch 15/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.3331 - acc: 0.1147 - val_loss: 0.7267 - val_acc: 0.0419
# Epoch 16/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.3173 - acc: 0.1222 - val_loss: 0.7234 - val_acc: 0.0427
# Epoch 17/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.3174 - acc: 0.1197 - val_loss: 0.7387 - val_acc: 0.0382
# Epoch 18/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.3176 - acc: 0.1179 - val_loss: 0.7384 - val_acc: 0.0429
# Epoch 19/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.3111 - acc: 0.1198 - val_loss: 0.7256 - val_acc: 0.0408
# Epoch 20/25
# 814/814 [==============================] - 41s 51ms/step - loss: 0.3037 - acc: 0.1238 - val_loss: 0.7222 - val_acc: 0.0423
# Epoch 21/25
# 814/814 [==============================] - 37s 45ms/step - loss: 0.2986 - acc: 0.1265 - val_loss: 0.7408 - val_acc: 0.0435
# Epoch 22/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2983 - acc: 0.1240 - val_loss: 0.7285 - val_acc: 0.0419
# Epoch 23/25
# 814/814 [==============================] - 37s 45ms/step - loss: 0.2932 - acc: 0.1255 - val_loss: 0.7218 - val_acc: 0.0400
# Epoch 24/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2885 - acc: 0.1294 - val_loss: 0.7484 - val_acc: 0.0402
# Epoch 25/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2859 - acc: 0.1295 - val_loss: 0.7316 - val_acc: 0.0411
# --------------------------------------------------
# --------------------------------------------------
# • 2 months onsite experience for reference application (file browser) development.
# • 6 months industrial training in advanced computing.
# • sound knowledge of porting web application in android phone and debugging using web inspector.
# • 3 months project experience in java (jsp & servlets) and oracle.
# • worked on technologies like less.js and node.js
# • efficient in debugging node application using node inspector.
# • experienced in creating web application using worker thread which increases performance.
# technical skill details
# programming
# languages
# c, c++ have relevant experience in programming and
# debugging applications on windows and linux
# platform
# java undergone 6 months training in jsp, servlets
# and core java
# scripting
# languages
# javascript have sound knowledge of javascript
# web designing html5, xml, css3,
# json
# expert with relevant experience in
# developing applications using these
# technologies
# ide sublime text ,visual
# cv
# aravind arivarasan
# career objective:
# to pursue a challenging and growth oriented career which would mould me into a complete
# professional by applying both my technical and interpersonal skills.
# professional summary:
# i am an associate software engineer at cordys(is now opentext) software india
# private limited having work experience of 1 year. software developer of applications
# using cordys bop 4.3, html5, css3, javascript, jquery, oojs, ajax, web services,
# mysql.
# education
# degree specialization university /
# institution
# city country cgpa year of
# passing
# bachelor of
#
# ---OUTPUT-----
#  good knowledge of comprehensive development experience in microsoft technologies application, application, web experience of software development using robot framework and having years of experience of experience in software development development and web web involved in the test test test test test test test procedures, bug tracking, experience in developing web application using worker thread thread increases increases experienced in developing web application using worker thread thread increases performance. experienced in developing web application using worker thread thread increases increasescareer objective:seeking a a challenging and challenging and mentally stimulating environment, me me to experience of software development cycle cycle (sdlc), development. having knowledge of experience in web application framework framework
#                                                   --------------------------------------------------
# Iteration: 13
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2799 - acc: 0.1290 - val_loss: 0.7292 - val_acc: 0.0417
# Epoch 2/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2792 - acc: 0.1289 - val_loss: 0.7473 - val_acc: 0.0408
# Epoch 3/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.2721 - acc: 0.1319 - val_loss: 0.7330 - val_acc: 0.0421
# Epoch 4/25
# 814/814 [==============================] - 37s 45ms/step - loss: 0.2668 - acc: 0.1341 - val_loss: 0.7354 - val_acc: 0.0406
# Epoch 5/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2626 - acc: 0.1364 - val_loss: 0.7319 - val_acc: 0.0406
# Epoch 6/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2671 - acc: 0.1346 - val_loss: 0.7267 - val_acc: 0.0404
# Epoch 7/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2617 - acc: 0.1347 - val_loss: 0.7298 - val_acc: 0.0423
# Epoch 8/25
# 814/814 [==============================] - 37s 45ms/step - loss: 0.2480 - acc: 0.1394 - val_loss: 0.7335 - val_acc: 0.0423
# Epoch 9/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.2558 - acc: 0.1370 - val_loss: 0.7456 - val_acc: 0.0427
# Epoch 10/25
# 814/814 [==============================] - 41s 51ms/step - loss: 0.2500 - acc: 0.1370 - val_loss: 0.7356 - val_acc: 0.0423
# Epoch 11/25
# 814/814 [==============================] - 43s 53ms/step - loss: 0.2395 - acc: 0.1413 - val_loss: 0.7355 - val_acc: 0.0423
# Epoch 12/25
# 814/814 [==============================] - 43s 52ms/step - loss: 0.2388 - acc: 0.1409 - val_loss: 0.7367 - val_acc: 0.0419
# Epoch 13/25
# 814/814 [==============================] - 44s 54ms/step - loss: 0.2377 - acc: 0.1411 - val_loss: 0.7383 - val_acc: 0.0415
# Epoch 14/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.2345 - acc: 0.1414 - val_loss: 0.7495 - val_acc: 0.0413
# Epoch 15/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.2286 - acc: 0.1436 - val_loss: 0.7336 - val_acc: 0.0421
# Epoch 16/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.2254 - acc: 0.1442 - val_loss: 0.7361 - val_acc: 0.0425
# Epoch 17/25
# 814/814 [==============================] - 39s 47ms/step - loss: 0.2237 - acc: 0.1445 - val_loss: 0.7370 - val_acc: 0.0419
# Epoch 18/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.2200 - acc: 0.1446 - val_loss: 0.7372 - val_acc: 0.0419
# Epoch 19/25
# 814/814 [==============================] - 39s 47ms/step - loss: 0.2137 - acc: 0.1467 - val_loss: 0.7413 - val_acc: 0.0404
# Epoch 20/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.2102 - acc: 0.1476 - val_loss: 0.7367 - val_acc: 0.0406
# Epoch 21/25
# 814/814 [==============================] - 38s 47ms/step - loss: 0.2111 - acc: 0.1468 - val_loss: 0.7505 - val_acc: 0.0376
# Epoch 22/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.2177 - acc: 0.1451 - val_loss: 0.7454 - val_acc: 0.0417
# Epoch 23/25
# 814/814 [==============================] - 38s 46ms/step - loss: 0.1960 - acc: 0.1512 - val_loss: 0.7415 - val_acc: 0.0402
# Epoch 24/25
# 814/814 [==============================] - 37s 46ms/step - loss: 0.1996 - acc: 0.1500 - val_loss: 0.7518 - val_acc: 0.0396
# Epoch 25/25
# 814/814 [==============================] - 39s 48ms/step - loss: 0.1995 - acc: 0.1502 - val_loss: 0.7399 - val_acc: 0.0392
# --------------------------------------------------
# --------------------------------------------------
# • experienced in developing projects using mvc techniques.
# • 6 months onsite experience for web application framework support.
# • 2 months onsite experience for reference application (file browser) development.
# • 6 months industrial training in advanced computing.
# • sound knowledge of porting web application in android phone and debugging using web inspector.
# • 3 months project experience in java (jsp & servlets) and oracle.
# • worked on technologies like less.js and node.js
# • efficient in debugging node application using node inspector.
# • experienced in creating web application using worker thread which increases performance.
# technical skill details
# programming
# languages
# c, c++ have relevant experience in programming and
# debugging applications on windows and linux
# platform
# java undergone 6 months training in jsp, servlets
# and core java
# scripting
# languages
# javascript have sound knowledge of javascript
# web designing html5, xml, css3,
# json
# expert with relevant experience in
# developing applications using these
# technologies
# ide sublime text ,visual
# cv
# aravind arivarasan
# career objective:
# to pursue a challenging and growth oriented career which would mould me into a complete
# professional by applying both my technical and interpersonal skills.
# professional summary:
# i am an associate software engineer at cordys(is now opentext) software india
# private limited having work experience of 1 year. software developer of applications
# using cordys bop 4.3, html5, css3, javascript, jquery, oojs, ajax, web services,
# mysql.
# education
# degree specialization university /
# institution
# city country cgpa year of
#
# ---OUTPUT-----
#  experienced in developing web application using worker thread which increases performance. experienced in developing web application using worker thread which increases performance. good knowledge of software development knowledge of testing api using rest client having 12+ years of experience in experience in android & software development experience in developing web application and worker thread which increases performance. knowledge in storage technologies (nas, san). experienced in developing web application using worker thread which increases performance. good knowledge of software developmentcareer objective:seeking a a challenging and challenging and mentally stimulating to so to deliver to harness exposure to agile methodologies and participated in daily scrum meetings, retrospective meetings having knowledge in the c of following leading ecommerce sites like toysrus,
#                                                   --------------------------------------------------
# Iteration: 14
# Train on 814 samples, validate on 204 samples
# Epoch 1/25
#  90/814 [==>...........................] - ETA: 31s - loss: 0.1882 - acc: 0.1486
